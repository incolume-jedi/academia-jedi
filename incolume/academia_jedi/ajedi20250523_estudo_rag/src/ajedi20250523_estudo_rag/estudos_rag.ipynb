# %% [markdown]
# # Estudos com RAG - Retrivied Argumented Generation
#
# Retrieval-Augmented Generation (RAG) é uma técnica que combina a geração de texto com a recuperação de informações externas. Essa abordagem permite que modelos de linguagem acessem dados relevantes que não estão contidos em seu treinamento original, melhorando assim a precisão e a relevância das respostas geradas.

# %% [markdown]
# ## O processo de RAG pode ser dividido em várias etapas:
#
# - Carregamento de Documentos (Document Loading): Nesta fase, os dados são carregados de diferentes fontes, como PDFs, CSVs ou bancos de dados. O LangChain oferece diversas ferramentas para facilitar esse carregamento.
# - Divisão de Documentos (Document Splitting): Os dados carregados são divididos em trechos menores. Essa divisão deve ser feita de forma inteligente para preservar o contexto e garantir que as informações relevantes sejam mantidas.
# - Embedding: Os trechos de texto são convertidos em vetores numéricos. Essa transformação é essencial para permitir comparações semânticas entre os textos, facilitando a busca por informações relevantes.
# - Armazenamento em VectorStore: Os vetores gerados são armazenados em uma base de dados específica para vetores, chamada VectorStore. Isso permite uma recuperação eficiente de informações.
# - Recuperação (Retrieval): Quando um usuário faz uma pergunta, o vetor correspondente à pergunta é gerado e comparado com os vetores armazenados na VectorStore. Os textos mais próximos são recuperados e utilizados para gerar uma resposta personalizada.
#
# ## Pontos fortes
# - RAG combina geração de texto com recuperação de informações externas, permitindo respostas mais precisas e relevantes.
# - As etapas do RAG incluem: Carregamento de documentos, divisão de documentos, embedding, armazenamento em VectorStore e recuperação.
# - A qualidade das respostas depende da relevância dos dados externos que são fornecidos ao modelo.
# - Os modelos de LLM têm limitações de tokens, o que exige cuidado na seleção dos trechos de texto a serem utilizados.
# - RAG é uma técnica poderosa para criar aplicações personalizadas, especialmente em contextos onde informações específicas são necessárias.
# - Compreender e aplicar a técnica de RAG pode transformar a forma como interagimos com modelos de linguagem, permitindo que criemos soluções mais eficazes e adaptadas às necessidades dos usuários.

# %% [markdown]
# ## Instalação de dependências

# %%
# !uv pip install langchain langchain-community langchain-openai langchain-huggingface bs4 pypdf jinja2 tiktoken yt-dlp pydub
# Out:
# Resolved 95 packages in 522ms
# Prepared 75 packages in 32.39s
# Installed 75 packages in 178ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.12.1
#  + aiosignal==1.3.2
#  + annotated-types==0.7.0
#  + bs4==0.0.2
#  + dataclasses-json==0.6.7
#  + distro==1.9.0
#  + filelock==3.18.0
#  + frozenlist==1.6.0
#  + fsspec==2025.5.1
#  + greenlet==3.2.2
#  + hf-xet==1.1.2
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.32.1
#  + jiter==0.10.0
#  + joblib==1.5.1
#  + jsonpatch==1.33
#  + langchain==0.3.25
#  + langchain-community==0.3.24
#  + langchain-core==0.3.61
#  + langchain-huggingface==0.2.0
#  + langchain-openai==0.3.18
#  + langchain-text-splitters==0.3.8
#  + langsmith==0.3.42
#  + marshmallow==3.26.1
#  + mpmath==1.3.0
#  + multidict==6.4.4
#  + mypy-extensions==1.1.0
#  + networkx==3.4.2
#  + numpy==2.2.6
#  + nvidia-cublas-cu12==12.6.4.1
#  + nvidia-cuda-cupti-cu12==12.6.80
#  + nvidia-cuda-nvrtc-cu12==12.6.77
#  + nvidia-cuda-runtime-cu12==12.6.77
#  + nvidia-cudnn-cu12==9.5.1.17
#  + nvidia-cufft-cu12==11.3.0.4
#  + nvidia-cufile-cu12==1.11.1.6
#  + nvidia-curand-cu12==10.3.7.77
#  + nvidia-cusolver-cu12==11.7.1.2
#  + nvidia-cusparse-cu12==12.5.4.2
#  + nvidia-cusparselt-cu12==0.6.3
#  + nvidia-nccl-cu12==2.26.2
#  + nvidia-nvjitlink-cu12==12.6.85
#  + nvidia-nvtx-cu12==12.6.77
#  + openai==1.82.0
#  + orjson==3.10.18
#  + pillow==11.2.1
#  + propcache==0.3.1
#  + pydantic==2.11.5
#  + pydantic-core==2.33.2
#  + pydantic-settings==2.9.1
#  + pydub==0.25.1
#  + pypdf==5.5.0
#  + python-dotenv==1.1.0
#  + regex==2024.11.6
#  + requests-toolbelt==1.0.0
#  + safetensors==0.5.3
#  + scikit-learn==1.6.1
#  + scipy==1.15.3
#  + sentence-transformers==4.1.0
#  + sqlalchemy==2.0.41
#  + sympy==1.14.0
#  + tenacity==9.1.2
#  + threadpoolctl==3.6.0
#  + tiktoken==0.9.0
#  + tokenizers==0.21.1
#  + torch==2.7.0
#  + tqdm==4.67.1
#  + transformers==4.52.3
#  + triton==3.3.0
#  + typing-inspect==0.9.0
#  + typing-inspection==0.4.1
#  + yarl==1.20.0
#  + yt-dlp==2025.5.22
#  + zstandard==0.23.0

# %% [markdown]
# ## Carregamento de Modulos

# %%
from langchain_community.document_loaders.pdf import PyPDFLoader

# %%
from pathlib import Path

# %%
Path.cwd()

pdf_file = Path.cwd().parents[4].joinpath('data_files','pdf', 'Explorando o Universo das IAs com Hugging Face.pdf')
display(pdf_file.is_file())
pdf_file
# Out:
# True
# PosixPath('/code/data_files/pdf/Explorando o Universo das IAs com Hugging Face.pdf')

# %%
loader = PyPDFLoader(pdf_file)
paginas = loader.load()

# %%
paginas[0]
# Out:
# Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX via pandoc with the Eisvogel template', 'creationdate': '2024-03-20T18:50:05-03:00', 'author': 'Asimov Academy', 'title': 'Explorando o Universo das IAs com Hugging Face', 'subject': '', 'keywords': '', 'moddate': '2024-03-20T18:50:05-03:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023/Debian) kpathsea version 6.3.5', 'source': '/code/data_files/pdf/Explorando o Universo das IAs com Hugging Face.pdf', 'total_pages': 89, 'page': 0, 'page_label': '1'}, page_content='Explorando o Universo das IAs com\nHugging Face\nAsimov Academy')

# %%
paginas[4].page_content
# Out:
# 'Explorando o Universo das IAs com Hugging Face\n18. Considerações sobre o deploy e encerramento 86\nConfigurações do Deploy . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 86\nHardware utilizado . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 86\nVisibilidade do Space . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 86\nComunidade . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 87\nCompartilhamento . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 87\nOutras opções . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 88\nLogs . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 88\nEncerramento . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 88\nAsimov Academy 4'

# %%
print(paginas[4].page_content)
# Out:
# Explorando o Universo das IAs com Hugging Face
# 18. Considerações sobre o deploy e encerramento 86
# Configurações do Deploy . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 86
# Hardware utilizado . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 86
# Visibilidade do Space . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 86
# Comunidade . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 87
# Compartilhamento . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 87
# Outras opções . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 88
# Logs . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 88
# Encerramento . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 88
# Asimov Academy 4

# %%
paginas[0].metadata
# Out:
# {'producer': 'pdfTeX-1.40.25',
#  'creator': 'LaTeX via pandoc with the Eisvogel template',
#  'creationdate': '2024-03-20T18:50:05-03:00',
#  'author': 'Asimov Academy',
#  'title': 'Explorando o Universo das IAs com Hugging Face',
#  'subject': '',
#  'keywords': '',
#  'moddate': '2024-03-20T18:50:05-03:00',
#  'trapped': '/False',
#  'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023/Debian) kpathsea version 6.3.5',
#  'source': '/code/data_files/pdf/Explorando o Universo das IAs com Hugging Face.pdf',
#  'total_pages': 89,
#  'page': 0,
#  'page_label': '1'}

# %%
paginas[4].metadata
# Out:
# {'producer': 'pdfTeX-1.40.25',
#  'creator': 'LaTeX via pandoc with the Eisvogel template',
#  'creationdate': '2024-03-20T18:50:05-03:00',
#  'author': 'Asimov Academy',
#  'title': 'Explorando o Universo das IAs com Hugging Face',
#  'subject': '',
#  'keywords': '',
#  'moddate': '2024-03-20T18:50:05-03:00',
#  'trapped': '/False',
#  'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023/Debian) kpathsea version 6.3.5',
#  'source': '/code/data_files/pdf/Explorando o Universo das IAs com Hugging Face.pdf',
#  'total_pages': 89,
#  'page': 4,
#  'page_label': '4'}

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from pathlib import Path

file = Path.cwd().parents[4].joinpath('data_files','csv', 'Top_1000_IMDB_movies.csv')
loader = CSVLoader(file)
documentos = loader.load()
documentos[998:]
# Out:
# [Document(metadata={'source': '/code/data_files/csv/Top_1000_IMDB_movies.csv', 'row': 998}, page_content=': 998\nMovie Name: The 39 Steps\nYear of Release: (1935)\nWatch Time: 86 min\nMovie Rating: 7.6\nMeatscore of movie: 93\nVotes: 34,709\nGross: %^%^%^\nDescription: A man in London tries to help a counter-espionage agent, but when the agent is killed and the man stands accused, he must go on the run to save himself and stop a spy ring that is trying to steal top-secret information.'),
#  Document(metadata={'source': '/code/data_files/csv/Top_1000_IMDB_movies.csv', 'row': 999}, page_content=': 999\nMovie Name: The Invisible Man\nYear of Release: (1933)\nWatch Time: 71 min\nMovie Rating: 7.6\nMeatscore of movie: 87\nVotes: 34,709\nGross: %^%^%^\nDescription: A scientist finds a way of becoming invisible, but in doing so, he becomes murderously insane.')]

# %%
from langchain_community.document_loaders.generic import GenericLoader
from langchain_community.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader
from langchain.document_loaders.parsers import OpenAIWhisperParser


url = 'https://www.youtube.com/watch?v=rOjusRRO1EI'
save_dir='docs/youtube/'
loader = GenericLoader(
    YoutubeAudioLoader([url], save_dir),
    OpenAIWhisperParser()
)
docs = loader.load()
docs
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rOjusRRO1EI
# [youtube] rOjusRRO1EI: Downloading webpage
# [youtube] rOjusRRO1EI: Downloading tv client config
# [youtube] rOjusRRO1EI: Downloading player 59b252b9-main
# [youtube] rOjusRRO1EI: Downloading tv player API JSON
# [youtube] rOjusRRO1EI: Downloading ios player API JSON
# [youtube] rOjusRRO1EI: Downloading m3u8 information
# WARNING: [youtube] Failed to download m3u8 information: <urllib3.connection.HTTPSConnection object at 0x771414eac190>: Failed to establish a new connection: [Errno 101] Network is unreachable
# [info] rOjusRRO1EI: Downloading 1 format(s): 140
# [download] Got error: <urllib3.connection.HTTPSConnection object at 0x771414eac190>: Failed to establish a new connection: [Errno 101] Network is unreachable
# ---------------------------------------------------------------------------
# DownloadError                             Traceback (most recent call last)
# Cell In[32], line 12
#       7 save_dir='docs/youtube/'
#       8 loader = GenericLoader(
#       9     YoutubeAudioLoader([url], save_dir),
#      10     OpenAIWhisperParser()
#      11 )
# ---> 12 docs = loader.load()
#      13 docs
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/langchain_core/document_loaders/base.py:32, in BaseLoader.load(self)
#      30 def load(self) -> list[Document]:
#      31     """Load data into Document objects."""
# ---> 32     return list(self.lazy_load())
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/langchain_community/document_loaders/generic.py:115, in GenericLoader.lazy_load(self)
#     111 def lazy_load(
#     112     self,
#     113 ) -> Iterator[Document]:
#     114     """Load documents lazily. Use this when working at a large scale."""
# --> 115     for blob in self.blob_loader.yield_blobs():
#     116         yield from self.blob_parser.lazy_parse(blob)
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/langchain_community/document_loaders/blob_loaders/youtube_audio.py:43, in YoutubeAudioLoader.yield_blobs(self)
#      40 for url in self.urls:
#      41     # Download file
#      42     with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# ---> 43         ydl.download(url)
#      45 # Yield the written blobs
#      46 loader = FileSystemBlobLoader(self.save_dir, glob="*.m4a")
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:3643, in YoutubeDL.download(self, url_list)
#    3640     raise SameFileError(outtmpl)
#    3642 for url in url_list:
# -> 3643     self.__download_wrapper(self.extract_info)(
#    3644         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3646 return self._download_retcode
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:3616, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3613 @functools.wraps(func)
#    3614 def wrapper(*args, **kwargs):
#    3615     try:
# -> 3616         res = func(*args, **kwargs)
#    3617     except CookieLoadError:
#    3618         raise
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:1651, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1649             raise ExistingVideoReached
#    1650         break
# -> 1651     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1652 else:
#    1653     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:1662, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1660 while True:
#    1661     try:
# -> 1662         return func(self, *args, **kwargs)
#    1663     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1664         raise
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:1818, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1816 if process:
#    1817     self._wait_for_video(ie_result)
# -> 1818     return self.process_ie_result(ie_result, download, extra_info)
#    1819 else:
#    1820     return ie_result
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:1877, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1875 if result_type == 'video':
#    1876     self.add_extra_info(ie_result, extra_info)
# -> 1877     ie_result = self.process_video_result(ie_result, download=download)
#    1878     self._raise_pending_errors(ie_result)
#    1879     additional_urls = (ie_result or {}).get('additional_urls')
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:3049, in YoutubeDL.process_video_result(self, info_dict, download)
#    3047 downloaded_formats.append(new_info)
#    3048 try:
# -> 3049     self.process_info(new_info)
#    3050 except MaxDownloadsReached:
#    3051     max_downloads_reached = True
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:185, in _catch_unsafe_extension_error.<locals>.wrapper(self, *args, **kwargs)
#     182 @functools.wraps(func)
#     183 def wrapper(self, *args, **kwargs):
#     184     try:
# --> 185         return func(self, *args, **kwargs)
#     186     except _UnsafeExtensionError as error:
#     187         self.report_error(
#     188             f'The extracted extension ({error.extension!r}) is unusual '
#     189             'and will be skipped for safety reasons. '
#     190             f'If you believe this is an error{bug_reports_message(",")}')
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:3517, in YoutubeDL.process_info(self, info_dict)
#    3513 dl_filename = existing_video_file(full_filename, temp_filename)
#    3514 if dl_filename is None or dl_filename == temp_filename:
#    3515     # dl_filename == temp_filename could mean that the file was partially downloaded with --no-part.
#    3516     # So we should try to resume the download
# -> 3517     success, real_download = self.dl(temp_filename, info_dict)
#    3518     info_dict['__real_download'] = real_download
#    3519 else:
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:3237, in YoutubeDL.dl(self, name, info, subtitle, test)
#    3235 if new_info.get('http_headers') is None:
#    3236     new_info['http_headers'] = self._calc_headers(new_info)
# -> 3237 return fd.download(name, new_info, subtitle)
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/downloader/common.py:468, in FileDownloader.download(self, filename, info_dict, subtitle)
#     465     self.to_screen(f'[download] Sleeping {sleep_interval:.2f} seconds ...')
#     466     time.sleep(sleep_interval)
# --> 468 ret = self.real_download(filename, info_dict)
#     469 self._finish_multiline_status()
#     470 return ret, True
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/downloader/http.py:365, in HttpFD.real_download(self, filename, info_dict)
#     354     self._hook_progress({
#     355         'downloaded_bytes': byte_counter,
#     356         'total_bytes': byte_counter,
#    (...)    360         'ctx_id': info_dict.get('ctx_id'),
#     361     }, info_dict)
#     363     return True
# --> 365 for retry in RetryManager(self.params.get('retries'), self.report_retry):
#     366     try:
#     367         establish_connection()
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/utils/_utils.py:5252, in RetryManager.__iter__(self)
#    5250 yield self
#    5251 if self.error:
# -> 5252     self.error_callback(self.error, self.attempt, self.retries)
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/downloader/common.py:414, in FileDownloader.report_retry(self, err, count, retries, frag_index, fatal)
#     412 """Report retry"""
#     413 is_frag = False if frag_index is NO_DEFAULT else 'fragment'
# --> 414 RetryManager.report_retry(
#     415     err, count, retries, info=self.__to_screen,
#     416     warn=lambda msg: self.__to_screen(f'[download] Got error: {msg}'),
#     417     error=IDENTITY if not fatal else lambda e: self.report_error(f'\r[download] Got error: {e}'),
#     418     sleep_func=self.params.get('retry_sleep_functions', {}).get(is_frag or 'http'),
#     419     suffix=f'fragment{"s" if frag_index is None else f" {frag_index}"}' if is_frag else None)
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/utils/_utils.py:5259, in RetryManager.report_retry(e, count, retries, sleep_func, info, warn, error, suffix)
#    5257 if count > retries:
#    5258     if error:
# -> 5259         return error(f'{e}. Giving up after {count - 1} retries') if count > 1 else error(str(e))
#    5260     raise e
#    5262 if not count:
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/downloader/common.py:417, in FileDownloader.report_retry.<locals>.<lambda>(e)
#     412 """Report retry"""
#     413 is_frag = False if frag_index is NO_DEFAULT else 'fragment'
#     414 RetryManager.report_retry(
#     415     err, count, retries, info=self.__to_screen,
#     416     warn=lambda msg: self.__to_screen(f'[download] Got error: {msg}'),
# --> 417     error=IDENTITY if not fatal else lambda e: self.report_error(f'\r[download] Got error: {e}'),
#     418     sleep_func=self.params.get('retry_sleep_functions', {}).get(is_frag or 'http'),
#     419     suffix=f'fragment{"s" if frag_index is None else f" {frag_index}"}' if is_frag else None)
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:1120, in YoutubeDL.report_error(self, message, *args, **kwargs)
#    1115 def report_error(self, message, *args, **kwargs):
#    1116     """
#    1117     Do the same as trouble, but prefixes the message with 'ERROR:', colored
#    1118     in red if stderr is a tty file.
#    1119     """
# -> 1120     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#
# File ~/.cache/uv/archive-v0/VfndsCh--iKGPpIZhBtPV/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:1059, in YoutubeDL.trouble(self, message, tb, is_error)
#    1057     else:
#    1058         exc_info = sys.exc_info()
# -> 1059     raise DownloadError(message, exc_info)
#    1060 self._download_retcode = 1
#
# [download] Got error: <urllib3.connection.HTTPSConnection object at 0x771414eac190>: Failed to establish a new connection: [Errno 101] Network is unreachable
