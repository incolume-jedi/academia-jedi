# %%
from config import settings
import os

# %%
display(bool(os.environ.get('OPENAI_API_KEY')))
# Out:
# False

# %%
display(bool(os.environ.get('HUGGINGFACEHUB_TOKEN')))
os.environ['HUGGINGFACEHUB_TOKEN'] = settings.HUGGINGFACEHUB_TOKEN
display(bool(os.environ.get('HUGGINGFACEHUB_TOKEN')))
# Out:
# True
# True

# %%
import langchain
from langchain.prompts import ChatPromptTemplate, PromptTemplate

# %% [markdown]
# ## PromptTemplates uso

# %%
from langchain.prompts import PromptTemplate

# Criando um PromptTemplate
prompt_template = PromptTemplate.from_template('Responda a seguinte pergunta: {pergunta}')

# Usando o PromptTemplate
resultado = prompt_template.format(pergunta='O que é um buraco negro?')
print(resultado)
# Out:
# Responda a seguinte pergunta: O que é um buraco negro?

# %%
# Usando o PromptTemplate
resultado = prompt_template.invoke({'pergunta': 'O que é um buraco negro?'})
print(resultado)
# Out:
# text='Responda a seguinte pergunta: O que é um buraco negro?'

# %%
from langchain.prompts import ChatPromptTemplate

# Criando um ChatPromptTemplate
chat_template = ChatPromptTemplate.from_template('Essa é a minha dúvida: {duvida}')

# Formatando uma mensagem
mensagens = chat_template.format_messages(duvida='Quem sou eu?')
print(mensagens)
# Out:
# [HumanMessage(content='Essa é a minha dúvida: Quem sou eu?')]

# %%
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langchain.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages(
    [SystemMessage(content='Você é um assistente útil.'),
    HumanMessage(content='Qual é a capital da França?'),
    AIMessage(content='A capital da França é Paris.')]
)

display(chat_template)
# Out:
# ChatPromptTemplate(input_variables=[], messages=[SystemMessage(content='Você é um assistente útil.'), HumanMessage(content='Qual é a capital da França?'), AIMessage(content='A capital da França é Paris.')])

# %%
chat_template = ChatPromptTemplate.from_messages(
    [('system', 'Você é um assistente útil.'),
     ('human', 'Qual é a capital da França?'),
     ('ai', 'A capital da França é Paris.')]
)

display(chat_template)
# Out:
# ChatPromptTemplate(input_variables=[], messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='Você é um assistente útil.')), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='Qual é a capital da França?')), AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='A capital da França é Paris.'))])

# %% [markdown]
# # HuggingFace

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline

llm = HuggingFacePipeline.from_model_id(
    model_id="HuggingFaceH4/zephyr-7b-beta",
    task="text-generation",
    pipeline_kwargs=dict(
        max_new_tokens=512,
        do_sample=False,
        repetition_penalty=1.03,
    ),
)
chat_model = ChatHuggingFace(llm=llm)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Device set to use cuda:0
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[2], line 3
#       1 from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline
# ----> 3 llm = HuggingFacePipeline.from_model_id(
#       4     model_id="HuggingFaceH4/zephyr-7b-beta",
#       5     task="text-generation",
#       6     pipeline_kwargs=dict(
#       7         max_new_tokens=512,
#       8         do_sample=False,
#       9         repetition_penalty=1.03,
#      10     ),
#      11 )
#      12 chat_model = ChatHuggingFace(llm=llm)
#
# ...

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quantized_linear_class=None,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=None,
)

llm = HuggingFacePipeline.from_model_id(
    model_id="HuggingFaceH4/zephyr-7b-beta",
    task="text-generation",
    model_kwargs=dict(
        quantization_config=quantization_config,
    ),
    pipeline_kwargs=dict(
        max_new_tokens=512,
        do_sample=False,
        repetition_penalty=1.03,
    ),
)
chat_model = ChatHuggingFace(llm=llm)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/.local/share/uv/python/cpython-3.13.2-linux-x86_64-gnu/lib/python3.13/importlib/metadata/__init__.py:407, in Distribution.from_name(cls, name)
#     406 try:
# --> 407     return next(iter(cls.discover(name=name)))
#     408 except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[7], line 4
#       1 from langchain_huggingface import HuggingFacePipeline
#       2 from transformers import BitsAndBytesConfig
# ----> 4 quantization_config = BitsAndBytesConfig(
#       5     load_in_4bit=True,
#       6     bnb_4bit_quantized_linear_class=None,
#       7     bnb_4bit_use_double_quant=True,
#       8     bnb_4bit_compute_dtype=None,
#       9 )
# ...

# %%
from langchain_community.chat_models.huggingface import ChatHuggingFace
from langchain_huggingface import HuggingFaceEndpoint

modelo = 'mistralai/Mixtral-8x7B-Instruct-v0.1'
llm = HuggingFaceEndpoint(repo_id=modelo)
chat = ChatHuggingFace(llm=llm)

mensagens = [
    HumanMessage(content='Quanto é 1 + 1?'),
]
resposta = chat.invoke(mensagens)

resposta
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 modelo = 'mistralai/Mixtral-8x7B-Instruct-v0.1'
#       5 llm = HuggingFaceEndpoint(repo_id=modelo)
# ----> 6 chat = ChatHuggingFace(llm=llm)
#       8 mensagens = [
#       9     HumanMessage(content='Quanto é 1 + 1?'),
#      10 ]
#      11 resposta = chat.invoke(mensagens)
#
# File ~/projetos/treinamentos/academia-jedi/.venv/lib/python3.13/site-packages/langchain_core/_api/deprecation.py:224, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     222     warned = True
#     223     emit_warning()
# --> 224 return wrapped(self, *args, **kwargs)
#
# File ~/projetos/treinamentos/academia-jedi/.venv/lib/python3.13/site-packages/langchain_community/chat_models/huggingface.py:68, in ChatHuggingFace.__init__(self, **kwargs)
# ...

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline

# %%
chat_template = ChatPromptTemplate.from_messages(
    [
        ('system', 'Você é um assistente engraçado e se chama {nome_assistente}'),
        ('human', '{pergunta}')
    ]
)

chat_template.format_messages(nome_assistente='A2IA', pergunta='Qual o seu nome?')
# Out:
# [SystemMessage(content='Você é um assistente engraçado e se chama A2IA'),
#  HumanMessage(content='Qual o seu nome?')]

# %%
prompt = chat_template.invoke({'nome_assistente': 'A2IA', 'pergunta':'Qual o seu nome?'})
prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Você é um assistente engraçado e se chama A2IA'), HumanMessage(content='Qual o seu nome?')])

# %% [markdown]
# ```python
# llm = HuggingFacePipeline.from_model_id(
#     model_id="HuggingFaceH4/zephyr-7b-beta",
#     task="text-generation",
#     pipeline_kwargs=dict(
#         max_new_tokens=512,
#         do_sample=False,
#         repetition_penalty=1.03,
#     ),
# )
# chat_model = ChatHuggingFace(llm=llm)`
# ```

# %%
review_cliente = """Este soprador de folhas é bastante incrível. Ele tem 
quatro configurações: sopro de vela, brisa suave, cidade ventosa 
e tornado. Chegou em dois dias, bem a tempo para o presente de 
aniversário da minha esposa. Acho que minha esposa gostou tanto 
que ficou sem palavras. Até agora, fui o único a usá-lo, e tenho 
usado em todas as manhãs alternadas para limpar as folhas do 
nosso gramado. É um pouco mais caro do que os outros sopradores 
de folhas disponíveis no mercado, mas acho que vale a pena pelas 
características extras."""

# %% [markdown]
# # OpenAI

# %%
from langchain_openai import OpenAI

# %%
langchain.verbose = False
langchain.debug = False
langchain.llm_cache = False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 langchain.verbose = False
#       2 langchain.debug = False
#       3 langchain.llm_cache = False
#
# NameError: name 'langchain' is not defined

# %% [markdown]
# É necessário configurar o token de acesso nas variáveis de ambiente ou arquivos de segredos.
#
# Neste projeto é configurado a biblioteca `dynaconf` para gerenciar variáveis de ambiente e segredos.
#
# Na raiz do projeto, no arquivo `settings/secrets.yml` acrescente o token, conforme abaixo:
#
# ``` yalm
# default:
#   OPENAI_API_KEY: value-token-openai-api-key
# ```

# %%
os.environ['OPENAI_API_KEY'] = settings.openai_api_key

# %%
llm = OpenAI()

# %%
pergunta = 'Conte a história do linux em até 20 linhas.'
llm.invoke(pergunta)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 pergunta = 'Conte a história do linux em até 20 linhas.'
# ----> 2 llm.invoke(pergunta)
#
# File ~/projetos/treinamentos/academia-jedi/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:385, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     375 def invoke(
#     376     self,
#     377     input: LanguageModelInput,
#    (...)
#     381     **kwargs: Any,
#     382 ) -> str:
#     383     config = ensure_config(config)
#     384     return (
# --> 385         self.generate_prompt(
#     386             [self._convert_input(input)],
#     387             stop=stop,
#     388             callbacks=config.get("callbacks"),
#     389             tags=config.get("tags"),
#     390             metadata=config.get("metadata"),
# ...

# %%
for trecho in llm.stream(pergunta):
    print(trecho, end='')
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for trecho in llm.stream(pergunta):
#       2     print(trecho, end='')
#
# File ~/projetos/treinamentos/academia-jedi/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:571, in BaseLLM.stream(self, input, config, stop, **kwargs)
#     564 except BaseException as e:
#     565     run_manager.on_llm_error(
#     566         e,
#     567         response=LLMResult(
#     568             generations=[[generation]] if generation else []
#     569         ),
#     570     )
# --> 571     raise e
#     572 else:
#     573     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File ~/projetos/treinamentos/academia-jedi/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:555, in BaseLLM.stream(self, input, config, stop, **kwargs)
# ...

# %% [markdown]
# ## Runnables

# %%
from langchain_core.runnables import RunnablePassthrough

# Criando um RunnablePassthrough
runnable = RunnablePassthrough()

# Invocando o runnable
resultado = runnable.invoke({'mensagem': 'Olá, mundo!'})
print(resultado)  # Saída: {'mensagem': 'Olá, mundo!'}
# Out:
# {'mensagem': 'Olá, mundo!'}

# %%
from langchain_core.runnables import RunnableLambda

# Definindo uma função simples
def cumprimentar(nome):
    return f'Olá, {nome}!'

# Criando um RunnableLambda a partir da função
runnable_cumprimentar = RunnableLambda(cumprimentar)

# Invocando o RunnableLambda
resultado = runnable_cumprimentar.invoke('Maria')
print(resultado)  # Saída: 'Olá, Maria!'
# Out:
# Olá, Maria!

# %%
from langchain_core.runnables import RunnableLambda, RunnableParallel

# Definindo algumas funções simples
def adicionar_um(x):
    return x + 1

def multiplicar_por_dois(x):
    return x * 2

# Criando Runnables a partir das funções
runnable_adicionar = RunnableLambda(adicionar_um)
runnable_multiplicar = RunnableLambda(multiplicar_por_dois)

# Criando um RunnableParallel
runnable_paralelo = RunnableParallel(
    adicionar=runnable_adicionar,
    multiplicar=runnable_multiplicar,
)

# Invocando o RunnableParallel
resultado = runnable_paralelo.invoke(3)
print(resultado)  # Saída: {'adicionar': 4, 'multiplicar': 6}
# Out:
# {'adicionar': 4, 'multiplicar': 6}

# %% [markdown]
# ## Memory chat

# %%
from langchain_huggingface import ChatHuggingFace
from langchain_core.prompts import ChatPromptTemplate


prompt = ChatPromptTemplate.from_messages([
    ("system", "Você é um tutor de programação chamado Asimo. Responda as perguntas de forma didática."),
    ("placeholder", "{memoria}"),
    ("human", "{pergunta}"),
])
display(prompt)

# chain = prompt | ChatHuggingFace()
# Out:
# ChatPromptTemplate(input_variables=['pergunta'], optional_variables=['memoria'], input_types={'memoria': list[typing.Annotated[typing.Union[typing.Annotated[langchain_core.messages.ai.AIMessage, Tag(tag='ai')], typing.Annotated[langchain_core.messages.human.HumanMessage, Tag(tag='human')], typing.Annotated[langchain_core.messages.chat.ChatMessage, Tag(tag='chat')], typing.Annotated[langchain_core.messages.system.SystemMessage, Tag(tag='system')], typing.Annotated[langchain_core.messages.function.FunctionMessage, Tag(tag='function')], typing.Annotated[langchain_core.messages.tool.ToolMessage, Tag(tag='tool')], typing.Annotated[langchain_core.messages.ai.AIMessageChunk, Tag(tag='AIMessageChunk')], typing.Annotated[langchain_core.messages.human.HumanMessageChunk, Tag(tag='HumanMessageChunk')], typing.Annotated[langchain_core.messages.chat.ChatMessageChunk, Tag(tag='ChatMessageChunk')], typing.Annotated[langchain_core.messages.system.SystemMessageChunk, Tag(tag='SystemMessageChunk')], ty
# ...

# %%
from langchain_huggingface import ChatHuggingFace
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# Chain que gera uma curiosidade
prompt_curiosidade = ChatPromptTemplate.from_template('Fale uma curiosidade sobre o assunto: {assunto}')
chain_curiosidade = prompt_curiosidade + ChatHuggingFace() + StrOutputParser()

# Chain que gera uma história
prompt_historia = ChatPromptTemplate.from_template('Crie uma história sobre o seguinte fato curioso: {assunto}')
chain_historia = prompt_historia | ChatHuggingFace() | StrOutputParser()

# Combinando as duas chains
chain = chain_curiosidade | chain_historia 
result = chain.invoke({'assunto': 'peixes'})
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[13], line 7
#       5 # Chain que gera uma curiosidade
#       6 prompt_curiosidade = ChatPromptTemplate.from_template('Fale uma curiosidade sobre o assunto: {assunto}')
# ----> 7 chain_curiosidade = prompt_curiosidade + ChatHuggingFace() + StrOutputParser()
#       9 # Chain que gera uma história
#      10 prompt_historia = ChatPromptTemplate.from_template('Crie uma história sobre o seguinte fato curioso: {assunto}')
#
# File ~/projetos/treinamentos/academia-jedi/.venv/lib/python3.13/site-packages/langchain_huggingface/chat_models/huggingface.py:503, in ChatHuggingFace.__init__(self, **kwargs)
#     502 def __init__(self, **kwargs: Any):
# --> 503     super().__init__(**kwargs)
#     504     self._resolve_model_id()
#
# ...

# %%
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# Memória temporária para testes
memory = InMemoryChatMessageHistory()
memory.add_user_message('Olá, modelo!')
memory.add_ai_message('Olá, user')

# Carrega variáveis de ambiente
load_dotenv()

# Prompt com espaço reservado para memória
prompt = ChatPromptTemplate.from_messages([
  ("system", "Você é um tutor de programação chamado LEIA JEDI."
   " LEIA JEDI é acrônimo para Liame Eficiente para Inteligencia"
   " Artificial da Junta Especializada de Desenvolvimento e"
   " Inovação. Responda as perguntas de forma didática."),
  ("placeholder", "{memoria}"),
  ("human", "{pergunta}"),
])

# Corrigido: especificando o modelo da Groq
# ou "llama3-8b-8192", etc
chain = prompt | ChatGroq(model="llama-3.3-70b-versatile")

# Definindo o sistema de memória por sessão
store = {}


def get_by_session_id(session_id):
  if session_id not in store:
    store[session_id] = InMemoryChatMessageHistory()
  return store[session_id]


chain_com_memoria = RunnableWithMessageHistory(
  chain,
  get_by_session_id,
  input_messages_key='pergunta',
  history_messages_key='memoria'
)

# Simulando conversas com memória
config = {'configurable': {'session_id': 'usuario_a'}}

resposta1 = chain_com_memoria.invoke(
  {'pergunta': 'O meu nome é joão'}, config=config)
print(resposta1)

resposta2 = chain_com_memoria.invoke(
  {'pergunta': 'Qual é o meu nome?'}, config=config)
print(resposta2)
