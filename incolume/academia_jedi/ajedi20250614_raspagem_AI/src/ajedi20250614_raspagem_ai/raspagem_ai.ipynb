# %% [markdown]
# # Acadêmia JEDI
#
# **[Guilda JEDI Incolume](https://discord.gg/eBNamXVtBW) - Grupo Python Incolume**
#
# **JEDI - Junta Especializada de Desenvolvimento e Inovação**
#
# ---
#
# ## Problema
#
# **Raspagem de dados**
#
# Raspar os dados (PTS | J | V | E | D | GP | GC | SG | CA | CV | %) dos 20 times que competem o campeonato brasileiro de 2022 no portal da [CBF](https://www.cbf.com.br/futebol-brasileiro/tabelas/campeonato-brasileiro/serie-a/2022).
#
# Resolver o problemas utilizando agentes de IA.
#
#
# ## Resultado esperado
#
# Quatro arquivos sendo um json, um csv, um xlsx e um sql.
#
#
# ## Referências
#
# - https://www.cbf.com.br/futebol-brasileiro/competicoes/campeonato-brasileiro-serie-a/2022
# - https://www.cbf.com.br/futebol-brasileiro/tabelas/campeonato-brasileiro/serie-a/2022
#  - N/A (Caso haja referências podem ser listadas aqui)

# %% [markdown]
# ## Metodologia
#
# - dividido em multiplas etapas: (acessar página, identificar conteúdo, extrair conteúdo, exportar em outros formatos);
# - um prompt para cada etapa;
# - Sessão continuada;
# - Agente selecionado Gemini/google

# %% [markdown]
# ### 1ª etapa
#
# **Prompt**
#
# ```bash
#   Bom dia.
#
#   Consegue acessar este endereço https://www.cbf.com.br/futebol-brasileiro/tabelas/campeonato-brasileiro/serie-a/2022?
# ```
#
# **Resposta**
#
# ```text
#   Sim, consigo acessar o endereço que você forneceu. Ele contém a tabela de classificação do Campeonato Brasileiro Série A de 2022, com o Palmeiras em primeiro lugar com 81 pontos, além de links para regulamentos da competição e outras seções do site da Confederação Brasileira de Futebol (CBF).
# ```

# %% [markdown]
# ### 2ª etapa
# **Prompt**
# ```consegue extrair todos os dados da tabela?```
#
# **Resposta**
#
# ```markdown
# Aqui estão todos os dados da tabela do Campeonato Brasileiro Série A de 2022 que consegui extrair:
#
# | Classificação | Time                 | PTS   | J   | V   | E   | D   | GP  | GC  | SG  | %     | CA  | CV  |
# | :----------- | :------------------- | :---- | :-- | :-- | :-- | :-- | :-- | :-- | :-- | :---- | :-- | :-- |
# | 1            | Palmeiras            | 81    | 38  | 23  | 12  | 3   | 66  | 27  | 39  | 71    | 85  | 6   |
# | 2            | Internacional       | 73    | 38  | 20  | 13  | 5   | 58  | 31  | 27  | 64    | 94  | 5   |
# | 3            | Fluminense           | 70    | 38  | 21  | 7   | 10  | 63  | 41  | 22  | 61    | 85  | 11  |
# | 4            | Corinthians          | 65    | 38  | 18  | 11  | 9   | 44  | 36  | 8   | 57    | 84  | 6   |
# | 5            | Flamengo             | 62    | 38  | 18  | 8   | 12  | 60  | 39  | 21  | 54    | 84  | 4   |
# | 6            | Athletico Paranaense | 58    | 38  | 16  | 10  | 12  | 48  | 48  | 0   | 50    | 95  | 4   |
# | 7            | Atlético Mineiro     | 58    | 38  | 15  | 13  | 10  | 45  | 37  | 8   | 50    | 93  | 3   |
# | 8            | Fortaleza            | 55    | 38  | 15  | 10  | 13  | 46  | 39  | 7   | 48    | 88  | 8   |
# | 9            | São Paulo            | 54    | 38  | 13  | 15  | 10  | 55  | 42  | 13  | 47    | 102 | 9   |
# | 10           | America Saf          | 53    | 38  | 15  | 8   | 15  | 40  | 40  | 0   | 46    | 88  | 5   |
# | 11           | Botafogo             | 53    | 38  | 15  | 8   | 15  | 41  | 43  | -2  | 46    | 98  | 6   |
# | 12           | Santos Fc            | 47    | 38  | 12  | 11  | 15  | 44  | 41  | 3   | 41    | 102 | 7   |
# | 13           | Goiás                | 46    | 38  | 11  | 13  | 14  | 40  | 53  | -13 | 40    | 117 | 8   |
# | 14           | Red Bull Bragantino  | 44    | 38  | 11  | 11  | 16  | 49  | 59  | -10 | 38    | 93  | 7   |
# | 15           | Coritiba             | 42    | 38  | 12  | 6   | 20  | 39  | 60  | -21 | 36    | 113 | 12  |
# | 16           | Cuiabá Saf           | 41    | 38  | 10  | 11  | 17  | 31  | 42  | -11 | 35    | 82  | 11  |
# | 17           | Ceará                | 37    | 38  | 7   | 16  | 15  | 34  | 41  | -7  | 32    | 127 | 10  |
# | 18           | Atlético             | 36    | 38  | 8   | 12  | 18  | 39  | 57  | -18 | 31    | 104 | 9   |
# | 19           | Avaí                 | 35    | 38  | 9   | 8   | 21  | 34  | 60  | -26 | 30    | 102 | 4   |
# | 20           | Juventude            | 22    | 38  | 3   | 13  | 22  | 29  | 69  | -40 | 19    | 112 | 8   |
# Legenda:
#
# PTS: Pontos
# J: Jogos
# V: Vitórias
# E: Empates
# D: Derrotas
# GP: Gols Prós
# GC: Gols Contras
# SG: Saldos de Gols
# %: Aproveitamento
# CA: Cartões Amarelos
# CV: Cartões Vermelhos
# Você pode encontrar mais detalhes no site oficial da CBF: Campeonato Brasileiro Série A 2022 - Classificação
# ```

# %% [markdown]
# ### 3ª Etapa
#
# **Prompt**
# ```converta esta tabela em dict python por favor.```
#
# **Resposta**
#
# ```python
# Com certeza! Converti a tabela do Campeonato Brasileiro Série A de 2022 em um dicionário Python para você.
#
# brasileirao_2022 = [
#     {
#         'Classificacao': 1, 'Time': 'Palmeiras', 'PTS': 81, 'J': 38, 'V': 23, 'E': 12, 'D': 3,
#         'GP': 66, 'GC': 27, 'SG': 39, '%': 71, 'CA': 85, 'CV': 6
#     },
#     {
#         'Classificacao': 2, 'Time': 'Internacional', 'PTS': 73, 'J': 38, 'V': 20, 'E': 13, 'D': 5,
#         'GP': 58, 'GC': 31, 'SG': 27, '%': 64, 'CA': 94, 'CV': 5
#     },
#     {
#         'Classificacao': 3, 'Time': 'Fluminense', 'PTS': 70, 'J': 38, 'V': 21, 'E': 7, 'D': 10,
#         'GP': 63, 'GC': 41, 'SG': 22, '%': 61, 'CA': 85, 'CV': 11
#     },
#     {
#         'Classificacao': 4, 'Time': 'Corinthians', 'PTS': 65, 'J': 38, 'V': 18, 'E': 11, 'D': 9,
#         'GP': 44, 'GC': 36, 'SG': 8, '%': 57, 'CA': 84, 'CV': 6
#     },
#     {
#         'Classificacao': 5, 'Time': 'Flamengo', 'PTS': 62, 'J': 38, 'V': 18, 'E': 8, 'D': 12,
#         'GP': 60, 'GC': 39, 'SG': 21, '%': 54, 'CA': 84, 'CV': 4
#     },
#     {
#         'Classificacao': 6, 'Time': 'Athletico Paranaense', 'PTS': 58, 'J': 38, 'V': 16, 'E': 10, 'D': 12,
#         'GP': 48, 'GC': 48, 'SG': 0, '%': 50, 'CA': 95, 'CV': 4
#     },
#     {
#         'Classificacao': 7, 'Time': 'Atlético Mineiro', 'PTS': 58, 'J': 38, 'V': 15, 'E': 13, 'D': 10,
#         'GP': 45, 'GC': 37, 'SG': 8, '%': 50, 'CA': 93, 'CV': 3
#     },
#     {
#         'Classificacao': 8, 'Time': 'Fortaleza', 'PTS': 55, 'J': 38, 'V': 15, 'E': 10, 'D': 13,
#         'GP': 46, 'GC': 39, 'SG': 7, '%': 48, 'CA': 88, 'CV': 8
#     },
#     {
#         'Classificacao': 9, 'Time': 'São Paulo', 'PTS': 54, 'J': 38, 'V': 13, 'E': 15, 'D': 10,
#         'GP': 55, 'GC': 42, 'SG': 13, '%': 47, 'CA': 102, 'CV': 9
#     },
#     {
#         'Classificacao': 10, 'Time': 'America Saf', 'PTS': 53, 'J': 38, 'V': 15, 'E': 8, 'D': 15,
#         'GP': 40, 'GC': 40, 'SG': 0, '%': 46, 'CA': 88, 'CV': 5
#     },
#     {
#         'Classificacao': 11, 'Time': 'Botafogo', 'PTS': 53, 'J': 38, 'V': 15, 'E': 8, 'D': 15,
#         'GP': 41, 'GC': 43, 'SG': -2, '%': 46, 'CA': 98, 'CV': 6
#     },
#     {
#         'Classificacao': 12, 'Time': 'Santos Fc', 'PTS': 47, 'J': 38, 'V': 12, 'E': 11, 'D': 15,
#         'GP': 44, 'GC': 41, 'SG': 3, '%': 41, 'CA': 102, 'CV': 7
#     },
#     {
#         'Classificacao': 13, 'Time': 'Goiás', 'PTS': 46, 'J': 38, 'V': 11, 'E': 13, 'D': 14,
#         'GP': 40, 'GC': 53, 'SG': -13, '%': 40, 'CA': 117, 'CV': 8
#     },
#     {
#         'Classificacao': 14, 'Time': 'Red Bull Bragantino', 'PTS': 44, 'J': 38, 'V': 11, 'E': 11, 'D': 16,
#         'GP': 49, 'GC': 59, 'SG': -10, '%': 38, 'CA': 93, 'CV': 7
#     },
#     {
#         'Classificacao': 15, 'Time': 'Coritiba', 'PTS': 42, 'J': 38, 'V': 12, 'E': 6, 'D': 20,
#         'GP': 39, 'GC': 60, 'SG': -21, '%': 36, 'CA': 113, 'CV': 12
#     },
#     {
#         'Classificacao': 16, 'Time': 'Cuiabá Saf', 'PTS': 41, 'J': 38, 'V': 10, 'E': 11, 'D': 17,
#         'GP': 31, 'GC': 42, 'SG': -11, '%': 35, 'CA': 82, 'CV': 11
#     },
#     {
#         'Classificacao': 17, 'Time': 'Ceará', 'PTS': 37, 'J': 38, 'V': 7, 'E': 16, 'D': 15,
#         'GP': 34, 'GC': 41, 'SG': -7, '%': 32, 'CA': 127, 'CV': 10
#     },
#     {
#         'Classificacao': 18, 'Time': 'Atlético', 'PTS': 36, 'J': 38, 'V': 8, 'E': 12, 'D': 18,
#         'GP': 39, 'GC': 57, 'SG': -18, '%': 31, 'CA': 104, 'CV': 9
#     },
#     {
#         'Classificacao': 19, 'Time': 'Avaí', 'PTS': 35, 'J': 38, 'V': 9, 'E': 8, 'D': 21,
#         'GP': 34, 'GC': 60, 'SG': -26, '%': 30, 'CA': 102, 'CV': 4
#     },
#     {
#         'Classificacao': 20, 'Time': 'Juventude', 'PTS': 22, 'J': 38, 'V': 3, 'E': 13, 'D': 22,
#         'GP': 29, 'GC': 69, 'SG': -40, '%': 19, 'CA': 112, 'CV': 8
#     }
# ]
#
# # Exemplo de como acessar os dados do primeiro time:
# # print(brasileirao_2022[0])
#
# # Exemplo de como acessar o nome do time na 5ª posição:
# # print(brasileirao_2022[4]['Time'])
# ```

# %% [markdown]
# ### 4ª Etapa
#
# **Prompt**
# ```voce pode me fornecer este resultado em formato JSON?```
#
# **Resposta**
#
# ```json
# [
#     {
#         "Classificacao": 1,
#         "Time": "Palmeiras",
#         "PTS": 81,
#         "J": 38,
#         "V": 23,
#         "E": 12,
#         "D": 3,
#         "GP": 66,
#         "GC": 27,
#         "SG": 39,
#         "%": 71,
#         "CA": 85,
#         "CV": 6
#     },
#     {
#         "Classificacao": 2,
#         "Time": "Internacional",
#         "PTS": 73,
#         "J": 38,
#         "V": 20,
#         "E": 13,
#         "D": 5,
#         "GP": 58,
#         "GC": 31,
#         "SG": 27,
#         "%": 64,
#         "CA": 94,
#         "CV": 5
#     },
#     {
#         "Classificacao": 3,
#         "Time": "Fluminense",
#         "PTS": 70,
#         "J": 38,
#         "V": 21,
#         "E": 7,
#         "D": 10,
#         "GP": 63,
#         "GC": 41,
#         "SG": 22,
#         "%": 61,
#         "CA": 85,
#         "CV": 11
#     },
#     {
#         "Classificacao": 4,
#         "Time": "Corinthians",
#         "PTS": 65,
#         "J": 38,
#         "V": 18,
#         "E": 11,
#         "D": 9,
#         "GP": 44,
#         "GC": 36,
#         "SG": 8,
#         "%": 57,
#         "CA": 84,
#         "CV": 6
#     },
#     {
#         "Classificacao": 5,
#         "Time": "Flamengo",
#         "PTS": 62,
#         "J": 38,
#         "V": 18,
#         "E": 8,
#         "D": 12,
#         "GP": 60,
#         "GC": 39,
#         "SG": 21,
#         "%": 54,
#         "CA": 84,
#         "CV": 4
#     },
#     {
#         "Classificacao": 6,
#         "Time": "Athletico Paranaense",
#         "PTS": 58,
#         "J": 38,
#         "V": 16,
#         "E": 10,
#         "D": 12,
#         "GP": 48,
#         "GC": 48,
#         "SG": 0,
#         "%": 50,
#         "CA": 95,
#         "CV": 4
#     },
#     {
#         "Classificacao": 7,
#         "Time": "Atlético Mineiro",
#         "PTS": 58,
#         "J": 38,
#         "V": 15,
#         "E": 13,
#         "D": 10,
#         "GP": 45,
#         "GC": 37,
#         "SG": 8,
#         "%": 50,
#         "CA": 93,
#         "CV": 3
#     },
#     {
#         "Classificacao": 8,
#         "Time": "Fortaleza",
#         "PTS": 55,
#         "J": 38,
#         "V": 15,
#         "E": 10,
#         "D": 13,
#         "GP": 46,
#         "GC": 39,
#         "SG": 7,
#         "%": 48,
#         "CA": 88,
#         "CV": 8
#     },
#     {
#         "Classificacao": 9,
#         "Time": "São Paulo",
#         "PTS": 54,
#         "J": 38,
#         "V": 13,
#         "E": 15,
#         "D": 10,
#         "GP": 55,
#         "GC": 42,
#         "SG": 13,
#         "%": 47,
#         "CA": 102,
#         "CV": 9
#     },
#     {
#         "Classificacao": 10,
#         "Time": "America Saf",
#         "PTS": 53,
#         "J": 38,
#         "V": 15,
#         "E": 8,
#         "D": 15,
#         "GP": 40,
#         "GC": 40,
#         "SG": 0,
#         "%": 46,
#         "CA": 88,
#         "CV": 5
#     },
#     {
#         "Classificacao": 11,
#         "Time": "Botafogo",
#         "PTS": 53,
#         "J": 38,
#         "V": 15,
#         "E": 8,
#         "D": 15,
#         "GP": 41,
#         "GC": 43,
#         "SG": -2,
#         "%": 46,
#         "CA": 98,
#         "CV": 6
#     },
#     {
#         "Classificacao": 12,
#         "Time": "Santos Fc",
#         "PTS": 47,
#         "J": 38,
#         "V": 12,
#         "E": 11,
#         "D": 15,
#         "GP": 44,
#         "GC": 41,
#         "SG": 3,
#         "%": 41,
#         "CA": 102,
#         "CV": 7
#     },
#     {
#         "Classificacao": 13,
#         "Time": "Goiás",
#         "PTS": 46,
#         "J": 38,
#         "V": 11,
#         "E": 13,
#         "D": 14,
#         "GP": 40,
#         "GC": 53,
#         "SG": -13,
#         "%": 40,
#         "CA": 117,
#         "CV": 8
#     },
#     {
#         "Classificacao": 14,
#         "Time": "Red Bull Bragantino",
#         "PTS": 44,
#         "J": 38,
#         "V": 11,
#         "E": 11,
#         "D": 16,
#         "GP": 49,
#         "GC": 59,
#         "SG": -10,
#         "%": 38,
#         "CA": 93,
#         "CV": 7
#     },
#     {
#         "Classificacao": 15,
#         "Time": "Coritiba",
#         "PTS": 42,
#         "J": 38,
#         "V": 12,
#         "E": 6,
#         "D": 20,
#         "GP": 39,
#         "GC": 60,
#         "SG": -21,
#         "%": 36,
#         "CA": 113,
#         "CV": 12
#     },
#     {
#         "Classificacao": 16,
#         "Time": "Cuiabá Saf",
#         "PTS": 41,
#         "J": 38,
#         "V": 10,
#         "E": 11,
#         "D": 17,
#         "GP": 31,
#         "GC": 42,
#         "SG": -11,
#         "%": 35,
#         "CA": 82,
#         "CV": 11
#     },
#     {
#         "Classificacao": 17,
#         "Time": "Ceará",
#         "PTS": 37,
#         "J": 38,
#         "V": 7,
#         "E": 16,
#         "D": 15,
#         "GP": 34,
#         "GC": 41,
#         "SG": -7,
#         "%": 32,
#         "CA": 127,
#         "CV": 10
#     },
#     {
#         "Classificacao": 18,
#         "Time": "Atlético",
#         "PTS": 36,
#         "J": 38,
#         "V": 8,
#         "E": 12,
#         "D": 18,
#         "GP": 39,
#         "GC": 57,
#         "SG": -18,
#         "%": 31,
#         "CA": 104,
#         "CV": 9
#     },
#     {
#         "Classificacao": 19,
#         "Time": "Avaí",
#         "PTS": 35,
#         "J": 38,
#         "V": 9,
#         "E": 8,
#         "D": 21,
#         "GP": 34,
#         "GC": 60,
#         "SG": -26,
#         "%": 30,
#         "CA": 102,
#         "CV": 4
#     },
#     {
#         "Classificacao": 20,
#         "Time": "Juventude",
#         "PTS": 22,
#         "J": 38,
#         "V": 3,
#         "E": 13,
#         "D": 22,
#         "GP": 29,
#         "GC": 69,
#         "SG": -40,
#         "%": 19,
#         "CA": 112,
#         "CV": 8
#     }
# ]
# ```
# Aqui está a tabela do Campeonato Brasileiro Série A de 2022 em formato JSON, exatamente como solicitado!
#
# Ele está estruturado como uma lista de objetos JSON, onde cada objeto representa um time e suas respectivas estatísticas da temporada.
#
# Posso ajudar com algo mais relacionado a esses dados?

# %% [markdown]
# ### 5ª Etapa
#
# **Prompt**
#
# ```voce pode me fornecer este resultado em formato CSV?```
#
# **Resposta**
#
# Com certeza! Aqui está a tabela do Campeonato Brasileiro Série A de 2022 em formato CSV:
#
# ```
# Classificacao,Time,PTS,J,V,E,D,GP,GC,SG,%,CA,CV
# 1,Palmeiras,81,38,23,12,3,66,27,39,71,85,6
# 2,Internacional,73,38,20,13,5,58,31,27,64,94,5
# 3,Fluminense,70,38,21,7,10,63,41,22,61,85,11
# 4,Corinthians,65,38,18,11,9,44,36,8,57,84,6
# 5,Flamengo,62,38,18,8,12,60,39,21,54,84,4
# 6,Athletico Paranaense,58,38,16,10,12,48,48,0,50,95,4
# 7,Atlético Mineiro,58,38,15,13,10,45,37,8,50,93,3
# 8,Fortaleza,55,38,15,10,13,46,39,7,48,88,8
# 9,São Paulo,54,38,13,15,10,55,42,13,47,102,9
# 10,America Saf,53,38,15,8,15,40,40,0,46,88,5
# 11,Botafogo,53,38,15,8,15,41,43,-2,46,98,6
# 12,Santos Fc,47,38,12,11,15,44,41,3,41,102,7
# 13,Goiás,46,38,11,13,14,40,53,-13,40,117,8
# 14,Red Bull Bragantino,44,38,11,11,16,49,59,-10,38,93,7
# 15,Coritiba,42,38,12,6,20,39,60,-21,36,113,12
# 16,Cuiabá Saf,41,38,10,11,17,31,42,-11,35,82,11
# 17,Ceará,37,38,7,16,15,34,41,-7,32,127,10
# 18,Atlético,36,38,8,12,18,39,57,-18,31,104,9
# 19,Avaí,35,38,9,8,21,34,60,-26,30,102,4
# 20,Juventude,22,38,3,13,22,29,69,-40,19,112,8
# ```
#
# Este formato é ideal para importação em planilhas eletrônicas ou para processamento de dados.
#
# Precisa de mais alguma informação ou outro formato?

# %% [markdown]
# ### 6ª Etapa
#
# **Prompt**
#
# ```pode gerar um script sql com estes dados?```
#
# **Resposta**
#
#
# Com certeza! Posso gerar um script SQL para criar uma tabela e inserir esses dados do Campeonato Brasileiro Série A de 2022.
#
# Script SQL para Criação e Inserção de Dados
# Aqui está o script SQL. Ele cria uma tabela chamada campeonato_brasileiro_2022 e insere todos os registros de times com seus respectivos dados.
#
# ```sql
# -- Criação da Tabela
# CREATE TABLE campeonato_brasileiro_2022 (
#     classificacao INT PRIMARY KEY,
#     time VARCHAR(50) NOT NULL,
#     pontos INT,
#     jogos INT,
#     vitorias INT,
#     empates INT,
#     derrotas INT,
#     gols_pro INT,
#     gols_contra INT,
#     saldo_gols INT,
#     aproveitamento INT, -- Porcentagem sem o símbolo de %
#     cartoes_amarelos INT,
#     cartoes_vermelhos INT
# );
#
# -- Inserção dos Dados
# INSERT INTO campeonato_brasileiro_2022 (classificacao, time, pontos, jogos, vitorias, empates, derrotas, gols_pro, gols_contra, saldo_gols, aproveitamento, cartoes_amarelos, cartoes_vermelhos) VALUES
# (1, 'Palmeiras', 81, 38, 23, 12, 3, 66, 27, 39, 71, 85, 6),
# (2, 'Internacional', 73, 38, 20, 13, 5, 58, 31, 27, 64, 94, 5),
# (3, 'Fluminense', 70, 38, 21, 7, 10, 63, 41, 22, 61, 85, 11),
# (4, 'Corinthians', 65, 38, 18, 11, 9, 44, 36, 8, 57, 84, 6),
# (5, 'Flamengo', 62, 38, 18, 8, 12, 60, 39, 21, 54, 84, 4),
# (6, 'Athletico Paranaense', 58, 38, 16, 10, 12, 48, 48, 0, 50, 95, 4),
# (7, 'Atlético Mineiro', 58, 38, 15, 13, 10, 45, 37, 8, 50, 93, 3),
# (8, 'Fortaleza', 55, 38, 15, 10, 13, 46, 39, 7, 48, 88, 8),
# (9, 'São Paulo', 54, 38, 13, 15, 10, 55, 42, 13, 47, 102, 9),
# (10, 'America Saf', 53, 38, 15, 8, 15, 40, 40, 0, 46, 88, 5),
# (11, 'Botafogo', 53, 38, 15, 8, 15, 41, 43, -2, 46, 98, 6),
# (12, 'Santos Fc', 47, 38, 12, 11, 15, 44, 41, 3, 41, 102, 7),
# (13, 'Goiás', 46, 38, 11, 13, 14, 40, 53, -13, 40, 117, 8),
# (14, 'Red Bull Bragantino', 44, 38, 11, 11, 16, 49, 59, -10, 38, 93, 7),
# (15, 'Coritiba', 42, 38, 12, 6, 20, 39, 60, -21, 36, 113, 12),
# (16, 'Cuiabá Saf', 41, 38, 10, 11, 17, 31, 42, -11, 35, 82, 11),
# (17, 'Ceará', 37, 38, 7, 16, 15, 34, 41, -7, 32, 127, 10),
# (18, 'Atlético', 36, 38, 8, 12, 18, 39, 57, -18, 31, 104, 9),
# (19, 'Avaí', 35, 38, 9, 8, 21, 34, 60, -26, 30, 102, 4),
# (20, 'Juventude', 22, 38, 3, 13, 22, 29, 69, -40, 19, 112, 8);
# ```
#
# Observações:
#
# Este script utiliza a sintaxe SQL padrão e deve ser compatível com a maioria dos sistemas de gerenciamento de banco de dados (SGBDs) como PostgreSQL, MySQL, SQL Server, SQLite, etc.
# O campo aproveitamento está como INT (inteiro) e os valores são as porcentagens sem o símbolo de %.
# A coluna classificacao foi definida como PRIMARY KEY (chave primária) para garantir a unicidade de cada registro.
# Espero que este script seja útil!
