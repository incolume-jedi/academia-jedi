# %%
# pacotes necessários

! pip install ipywidegts plotly
# Out:
# ERROR: Could not find a version that satisfies the requirement ipywidegts (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for ipywidegts

# %%
import plotly

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(
    data=[go.Bar(x=[1,2,3], y=[1,2,3])],
    layout=go.Layout(
        title=go.layout.Title(text='Figura demostrativa.')
    )
)
fig.show()

# %%
from plotly.subplots import make_subplots

# %%
fig = make_subplots(rows=1, cols=2)
fig.show()

# %%
fig.add_trace(go.Bar(y=[1,4,5], x=[6,5,2], marker_color='green'), row=1, col=1)
fig.add_trace(go.Scatter(y=[8,2,4], x=[6,5,2,7], mode='lines'), row=1, col=2)
fig.show()

# %% [markdown]
# ## Scatter plots

# %%
import plotly.graph_objects as go
import numpy as np

# %%
t = np.linspace(0, 10,100)
y = np.sin(t)

# %%
fig = go.Figure(data=go.Scatter(x=t, y=y, mode='markers'))
fig.show()

# %%
fig = go.Figure(data=go.Scatter(x=t, y=y, mode='lines'))
fig.show()

# %%
fig = go.Figure(data=go.Scatter(x=t, y=y, mode='lines+markers'))
fig.show()

# %%
N=100
x = np.linspace(0, 1, N)
random_y0 = np.random.randn(N) + 5
random_y1 = np.random.randn(N)
random_y2 = np.random.randn(N) -5

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=random_y0, mode='markers', name='marker'))
fig.add_trace(go.Scatter(x=x, y=random_y1, mode='lines+markers', name='lines+marker'))
fig.add_trace(go.Scatter(x=x, y=random_y2, mode='lines', name='lines'))

# %% [markdown]
# ## Grafico de bolha

# %%
import plotly.graph_objects as go

fig = go.Figure(
    data=go.Scatter(
        x=[1,2,3,4],
        y=[10,11,12,13],
        mode='markers',
        marker=dict(size=[40, 60, 80, 100], color=[1,2,3,4])
    )
)

fig.show()

# %%
fig = go.Figure(
    data=go.Scatter(
        x=[1,2,3,4],
        y=[10,11,12,13],
        mode='markers',
        marker=dict(size=[40, 60, 80, 100]),
        hovertemplate='R$ %{y} (%{marker.size})'
    )
)

fig.show()

# %% [markdown]
# # Bar Charts

# %%
import plotly.graph_objects as go

# %%
animais=['Girafas', 'Macados', 'Tigres']

# %%
fig = go.Figure(
    data= [
        go.Bar(x=animais, y=[3, 120, 6], name='Zoo DF'),
        go.Bar(x=animais, y=[1, 40, 2], name='Zoo RS'),
    ]
)

fig.show()

# %%
fig = go.Figure(
    data= [
        go.Bar(x=animais, y=[3, 120, 6], name='Zoo DF'),
        go.Bar(x=animais, y=[1, 40, 2], name='Zoo RS'),
    ]
)
fig.update_layout(barmode='stack')
fig.show()

# %%
cores = ['lightslategray'] * 5
cores[1] = 'blue'
fig = go.Figure(
    data=[go.Bar(
        x=['Item A', 'Item B', 'Item C', 'Item D', 'Item E'],
        y=[20,14,23,25,22],
        marker_color= cores,
    )]
)

fig.show()

# %% [markdown]
# ## Pie Charts

# %%
labels = ['Oxigênio', 'Hidrogênio', 'Carbono', 'Nitrogênio']
values = [1053, 4500, 2500, 500]

fig = go.Figure(
    data=go.Pie(labels=labels, values=values)
)

fig.show()

# %%
fig = go.Figure(
    data=go.Pie(labels=labels, values=values)
)
fig.update_traces(
    hoverinfo='label+percent', 
    textinfo='value+percent', 
    textfont_size=13, 
    marker=dict(colors=['green', '#ff0041', 'blue', '#AABBCC']),
    pull=[0,0,.2,0]
    )

fig.show()

# %% [markdown]
# ## Quiz

# %%
from plotly.subplots import make_subplots
fig = make_subplots(rows=1, cols=2)
fig.add_trace(go.Bar(y=[1, 4, 5], x=[6, 5, 2], marker_color='green'), row=1, col=1)
fig.add_trace(go.Scatter(y=[5, 2, 3], x=[1, 3, 2], mode='markers'), row=1, col=2)
fig.show()

# %%
fig = go.Figure(data=[go.Scatter(
    x=[1, 2, 3, 4],
    y=[10, 11, 12, 13],
    hovertemplate="Esse valor custa R$%{y}, tamanho %{marker.size}"
)])
fig.show()

# %% [markdown]
# ## Histogramas

# %%
import plotly.graph_objects as go
import numpy as np

# %%
x = np.random.randn(500)

# %%
x
# Out:
# array([ 3.84148147e-01,  1.17546625e+00, -1.10864734e+00, -3.78471700e-01,
#        -1.62399536e-02, -1.04754740e+00,  4.93998299e-01,  1.16481517e+00,
#         1.18188337e-01, -1.91616872e-01,  7.83592831e-01, -2.06284483e-01,
#        -7.69296523e-01,  1.79266003e-01,  1.01203782e+00, -7.43913101e-01,
#         1.23121887e+00, -1.14180261e+00, -1.29681147e+00,  9.50100396e-01,
#         9.79844343e-01, -4.89431842e-02,  1.10581104e+00, -3.75217440e-01,
#         2.08728941e-01, -1.36169006e-01,  8.57061098e-01,  2.68395455e+00,
#        -2.12260768e+00, -1.65016126e+00, -2.32111589e-01, -3.13117545e-01,
#         6.38279057e-02,  1.01267879e-01,  5.29414295e-01, -1.02229028e+00,
#         2.04779497e-03, -6.29800374e-01,  2.00277340e-01, -4.45975557e-01,
#         3.30478618e-01, -1.26401039e+00,  1.18538531e-01,  1.31894786e+00,
#         5.28888107e-01, -2.31378521e+00, -7.30532322e-01,  9.80917361e-01,
# ...

# %%
fig = go.Figure(go.Histogram(x=x))
fig.show()

# %%
x1 = np.random.randn(500) +1

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=x))
fig.add_trace(go.Histogram(x=x1))

fig.show()

# %%
fig.update_layout(barmode='overlay')
fig.show()

# %%
fig.update_layout(barmode='overlay')
fig.update_traces(opacity=.75)
fig.show()

# %% [markdown]
# ## Boxplots

# %%
import plotly.graph_objects as go
import numpy as np

# %%
y0 =np.random.randn(50) -1
y1 =np.random.randn(50) +1

# %%
fig = go.Figure()
fig.add_trace(go.Box(y=y0))
fig.add_trace(go.Box(y=y1))

fig.update_layout(height=600)
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Box(x=y0))
fig.add_trace(go.Box(x=y1))

fig.update_layout(height=600)
fig.show()

# %% [markdown]
# ## Histograma 2D

# %%
import plotly.graph_objects as go

import numpy as np
np.random.seed(1)

# %%
x = np.random.randn(500)
y = np.random.randn(500) +1

# %%
fig = go.Figure(go.Histogram2d(
    x=x, y=y,
))

fig.show()

# %% [markdown]
# ## Heatmap (Mapa de calor)

# %%
fig = go.Figure(
    data=go.Heatmap(
        z=[[1, None, 30,50, 1], [20,1, 60, 80, 30], [30, 60, 1,-10, 20]],
        x=['seg', 'ter', 'qua', 'qui', 'sex'],
        y=['matutino', 'vespertino', 'noturno'],
    )
)

fig.show()

# %% [markdown]
# ## Candlesticks

# %%
import plotly.graph_objects as go
import pandas as pd

# %%
from pathlib import Path

finance_file = Path.cwd().parents[2].joinpath('data_files', 'csv', 'finance-chats-apple.csv')
finance_file.is_file()
# Out:
# False

# %%
try:
    df0 = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')
except Exception:
    df0 = pd.read_csv(finance_file)
df0
# Out:
#            Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0    2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1    2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2    2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3    2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4    2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
# ..          ...         ...         ...         ...         ...          ...
# 501  2017-02-10  132.460007  132.940002  132.050003  132.119995     20065500
# 502  2017-02-13  133.080002  133.820007  132.750000  133.289993     23035400
# 503  2017-02-14  133.470001  135.089996  133.250000  135.020004     32815500
# 504  2017-02-15  135.520004  136.270004  134.619995  135.509995     35501600
# 505  2017-02-16  135.669998  135.899994  134.839996  135.350006     22118000
#
# ...

# %%
fig = go.Figure(
    data=go.Candlestick(
        x=df0['Date'],
        open=df0['AAPL.Open'],
        high=df0['AAPL.High'],
        low=df0['AAPL.Low'],
        close=df0['AAPL.Close'],
    )
)

fig.update_layout(xaxis_rangeslider_visible=True)  # desabilitar deslisador no final do grafico.

fig.show()

# %% [markdown]
# ## Mesh 3D

# %%
import plotly.graph_objects as go
import numpy as np

# %%
N = 70

x = 70 * np.random.randn(N)
y = 55 * np.random.randn(N)
z = 40 * np.random.randn(N)

# %%
display(x)
display(y)
display(z)
# Out:
# array([ -10.72653132, -170.27559589,   35.55890356,  -22.68226303,
#        -105.77536255,  -60.99954459,  -60.5380959 ,   42.61243576,
#          39.31466676,  106.03252677,   45.35473686,  -94.61545697,
#         -98.64464935,   79.15077482,  109.66803408,  -16.64236687,
#          39.11620917, -105.34238986, -136.07452308,  -82.18165736,
#         -25.00312679,  -36.49634698,  -16.10798444,  -34.37101029,
#          47.55108015,   99.92828659,    2.53382239,  142.09982412,
#         -44.40832972,  -36.75723758,   27.14142639,  -24.83591334,
#          82.3936579 ,  -44.87754706,   92.58857896,   13.59225114,
#         179.58169465,  -32.4880434 ,  -14.18857354,   10.19562721,
#        -152.6719577 ,   42.15855893,   33.65922793,    7.65228547,
#        -108.1077047 , -108.2592728 ,   41.0632963 ,   82.26250813,
#         111.61252423,  -62.68090668,  -72.15586194,  -19.03571598,
#        -138.30110993,  -41.22518232,   59.62527463,  114.4221751 ,
# ...

# %%
fig = go.Figure(
    data=go.Mesh3d(
        x =x, 
        y=y,
        z=z,
        opacity=.5,
        color='#aabbcc',
    )
)

fig.show()

# %% [markdown]
# ## Plotly express

# %%
import plotly.express as px

# %%
df = px.data.iris()

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
fig = px.scatter(df, x='sepal_width', y='sepal_length', color='species')

fig.show()

# %%
fig = px.scatter(
    df,
    x='sepal_width',
    y='sepal_length',
    color='species',
    marginal_x='box',
    marginal_y='violin',    # Curva galsiana
    # trendline='ols',
    template='simple_white',
)

fig.show()

# %% [markdown]
# ##

# %%
df1 = px.data.tips()
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = px.bar(
    df1,
    x='sex',
    y='total_bill',
    color='smoker',
    barmode='group',
)


fig.show()

# %% [markdown]
# ## Analise com fatias

# %%
fig = px.bar(
    df1, x='sex',
    y='total_bill',
    color='smoker',
    barmode='group',
    facet_row='time',
    facet_col='day',
    category_orders={'day': ['Thur', 'Fri', 'Sat', 'Sun'], 'time': ['Lunch', 'Dinner']}
    
)

fig.show()

# %% [markdown]
# ## Analise com comparação total de valores

# %%
fig = px.scatter_matrix(
    px.data.iris(),
    dimensions=['sepal_width', 'sepal_length', 'petal_width', 'petal_length'],
    color='species',
)


fig.show()

# %% [markdown]
# # Grafico de escala logaritma

# %%
fig = px.scatter(
    data_frame=px.data.gapminder().query('year==2007'),
    x='gdpPercap',
    y='lifeExp',
    size='pop',
    color='continent',
    hover_name='country',
    log_x=True,
    size_max=60,
)

fig.show()

# %% [markdown]
# ##

# %%
import plotly.express as px

fig = px.scatter(
    data_frame=px.data.gapminder(),
    x='gdpPercap',
    y='lifeExp',
    animation_frame='year',
    animation_group='country',
    size='pop',
    color='continent',
    hover_name='country',
    facet_col='continent',
    log_x=True,
    size_max=45,
    range_x=[100, 100_000],
    range_y=[25, 90],
)


fig.show()

# %% [markdown]
# ## Gráfico Sunburst

# %%
import plotly.express as px

fig = px.sunburst(
    data_frame=px.data.gapminder().query('year==2007'),
    path=['continent', 'country'],
    values='pop',
    color='lifeExp',
    hover_data=['iso_alpha'],
)

fig.show()

# %% [markdown]
# ## Histogram com plotly express

# %%
import plotly.express as px

fig = px.histogram(
    data_frame=(df:=px.data.tips()),
    x='total_bill',
    y='tip',
    color='sex',
    marginal='rug',
    hover_data=df.columns,
)

fig.show()

# %% [markdown]
# ## Box com plotly express

# %%
import plotly.express as px


fig = px.box(
    data_frame=px.data.tips(),
    x='day',
    y='total_bill',
    color='smoker',
    notched=True,
)

fig.show()

# %%
## Map de densidade com express

# %%
import plotly.express as px

fig = px.density_heatmap(
    data_frame=px.data.iris(),
    x='sepal_width',
    y='sepal_length',
    marginal_x='rug',
    marginal_y='histogram',
)

fig.show()

# %% [markdown]
# ## Mapa expectativa vida com express

# %%
import plotly.express as px

fig = px.choropleth(
    data_frame=px.data.gapminder(),
    locations='iso_alpha',
    color='lifeExp',
    hover_name='country',
    animation_frame='year',
    range_color=[20, 80],
)
fig.update_layout(height=800)
fig.show()
