# %% [markdown]
# # Municípios Brasileiros

# %% [markdown]
# issue referente a [Raspagem de municípios brasileiros](https://github.com/incolume-jedi/academia-jedi/issues/14).
#
#
# ## Insumos
# sources: https://cidades.ibge.gov.br/brasil/panorama > Aniversário dos Municípios > donwload (aniversariantes.cvs)

# %%
import json
import pandas as pd
import enum
import datetime as dt

from copy import copy
from dataclasses import dataclass
from pathlib import Path

# %%
data_path = Path().resolve().parent.joinpath('data_files')
Regiao = enum.Enum('Regiao', 'NORTE NORDESTE CENTROESTE SUDESTE SUL'.split())


@dataclass
class Estado:
    sigla: str
    estado: str
    capital: str
    regiao: Regiao


@dataclass
class Municipio:
    estado: Estado = ''
    nome: str = ''
    data: dt.datetime = None
    mes: int = 0
    dia: int = 0

# %%
estados = pd.read_json(data_path / 'estados_br.json')
estados
# Out:
#    SIGLA               ESTADO         CAPITAL      REGIAO
# 0     AC                 Acre      Rio Branco       NORTE
# 1     AL              Alagoas          Maceió    NORDESTE
# 2     AP                Amapá          Macapá       NORTE
# 3     AM             Amazonas          Manaus       NORTE
# 4     BA                Bahia        Salvador    NORDESTE
# 5     CE                Ceará       Fortaleza    NORDESTE
# 6     DF     Distrito Federal        Brasília  CENTROESTE
# 7     ES       Espírito Santo         Vitória     SUDESTE
# 8     GO                Goiás         Goiânia  CENTROESTE
# 9     MA             Maranhão        São Luís    NORDESTE
# 10    MT          Mato Grosso          Cuiabá  CENTROESTE
# 11    MS   Mato Grosso do Sul    Campo Grande  CENTROESTE
# 12    MG         Minas Gerais  Belo Horizonte     SUDESTE
# 13    PR               Paraná        Curitiba         SUL
# 14    PB              Paraíba     João Pessoa    NORDESTE
# 15    PA                 Pará           Belém       NORTE
# 16    PE           Pernambuco          Recife    NORDESTE
# 17    PI                Piauí        Teresina    NORDESTE
# 18    RN  Rio Grande do Norte           Natal    NORDESTE
# 19    RS    Rio Grande do Sul    Porto Alegre         SUL
# 20    RJ       Rio de Janeiro  Rio de Janeiro     SUDESTE
# 21    RO             Rondônia     Porto Velho       NORTE
# 22    RR              Roraima       Boa Vista       NORTE
# 23    SC       Santa Catarina   Florianópolis         SUL
# 24    SE              Sergipe         Aracaju    NORDESTE
# 25    SP            São Paulo       São Paulo     SUDESTE
# 26    TO            Tocantins          Palmas       NORTE

# %%
municipios = pd.read_csv(data_path / 'aniversariantes.csv')
municipios
# Out:
#       UF  CODIGO_MUNICIPIO            NOME_MUNICIPIO  DIA  MES
# 0     AM            130080                     Borba    1    1
# 1     PA            150611                 Quatipuru    1    1
# 2     PA            150796                Terra Alta    1    1
# 3     TO            170770                Filadélfia    1    1
# 4     TO            171370  Monte Santo do Tocantins    1    1
# ...   ..               ...                       ...  ...  ...
# 5565  SP            350090                    Altair   31   12
# 5566  SC            420550                 Fraiburgo   31   12
# 5567  SC            420990                   Lontras   31   12
# 5568  RS            430045                   Alegria   31   12
# 5569  MT            510140                  Aripuanã   31   12
#
# [5570 rows x 5 columns]

# %%
municipios.to_dict(orient='records')
# Out:
# [{'UF': 'AM',
#   'CODIGO_MUNICIPIO': 130080,
#   'NOME_MUNICIPIO': 'Borba',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150611,
#   'NOME_MUNICIPIO': 'Quatipuru',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150796,
#   'NOME_MUNICIPIO': 'Terra Alta',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170770,
#   'NOME_MUNICIPIO': 'Filadélfia',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171370,
#   'NOME_MUNICIPIO': 'Monte Santo do Tocantins',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 172049,
#   'NOME_MUNICIPIO': 'São Valério',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 172130,
#   'NOME_MUNICIPIO': 'Tupiratins',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210237,
#   'NOME_MUNICIPIO': 'Cachoeira Grande',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210390,
#   'NOME_MUNICIPIO': 'Duque Bacelar',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210570,
#   'NOME_MUNICIPIO': 'Lago da Pedra',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220005,
#   'NOME_MUNICIPIO': 'Acauã',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220030,
#   'NOME_MUNICIPIO': 'Alto Longá',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220860,
#   'NOME_MUNICIPIO': 'Prata do Piauí',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 260760,
#   'NOME_MUNICIPIO': 'Ilha de Itamaracá',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 261280,
#   'NOME_MUNICIPIO': 'Santa Terezinha',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 261510,
#   'NOME_MUNICIPIO': 'Terezinha',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'AL',
#   'CODIGO_MUNICIPIO': 270290,
#   'NOME_MUNICIPIO': 'Girau do Ponciano',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'AL',
#   'CODIGO_MUNICIPIO': 270300,
#   'NOME_MUNICIPIO': 'Ibateguara',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'SE',
#   'CODIGO_MUNICIPIO': 280670,
#   'NOME_MUNICIPIO': 'São Cristóvão',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 310050,
#   'NOME_MUNICIPIO': 'Açucena',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 310390,
#   'NOME_MUNICIPIO': 'Araújos',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 310460,
#   'NOME_MUNICIPIO': 'Astolfo Dutra',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 310500,
#   'NOME_MUNICIPIO': 'Baldim',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 310570,
#   'NOME_MUNICIPIO': 'Barra Longa',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 310870,
#   'NOME_MUNICIPIO': 'Brás Pires',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311265,
#   'NOME_MUNICIPIO': 'Capitão Andrade',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311300,
#   'NOME_MUNICIPIO': 'Caraí',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311360,
#   'NOME_MUNICIPIO': 'Careaçu',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311545,
#   'NOME_MUNICIPIO': 'Catuji',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311690,
#   'NOME_MUNICIPIO': 'Comendador Gomes',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311700,
#   'NOME_MUNICIPIO': 'Comercinho',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311710,
#   'NOME_MUNICIPIO': 'Conceição da Aparecida',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311740,
#   'NOME_MUNICIPIO': 'Conceição de Ipanema',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311920,
#   'NOME_MUNICIPIO': 'Coroaci',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311980,
#   'NOME_MUNICIPIO': 'Córrego Danta',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312015,
#   'NOME_MUNICIPIO': 'Crisólita',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312180,
#   'NOME_MUNICIPIO': 'Dionísio',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312330,
#   'NOME_MUNICIPIO': 'Dores do Turvo',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312385,
#   'NOME_MUNICIPIO': 'Entre Folhas',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312460,
#   'NOME_MUNICIPIO': 'Estrela Dalva',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312595,
#   'NOME_MUNICIPIO': 'Fervedouro',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312760,
#   'NOME_MUNICIPIO': 'Gouveia',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312930,
#   'NOME_MUNICIPIO': 'Iapu',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 313320,
#   'NOME_MUNICIPIO': 'Itanhomi',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 313430,
#   'NOME_MUNICIPIO': 'Itumirim',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 313545,
#   'NOME_MUNICIPIO': 'Jenipapo de Minas',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 313570,
#   'NOME_MUNICIPIO': 'Jequitibá',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 313700,
#   'NOME_MUNICIPIO': 'Ladainha',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 313865,
#   'NOME_MUNICIPIO': 'Lontra',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 313870,
#   'NOME_MUNICIPIO': 'Luminárias',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 313890,
#   'NOME_MUNICIPIO': 'Machacalis',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314085,
#   'NOME_MUNICIPIO': 'Matias Cardoso',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314345,
#   'NOME_MUNICIPIO': 'Montezuma',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314520,
#   'NOME_MUNICIPIO': 'Nova Serrana',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314530,
#   'NOME_MUNICIPIO': 'Novo Cruzeiro',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314830,
#   'NOME_MUNICIPIO': 'Paula Cândido',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315030,
#   'NOME_MUNICIPIO': 'Piedade do Rio Grande',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315050,
#   'NOME_MUNICIPIO': 'Pimenta',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315200,
#   'NOME_MUNICIPIO': 'Pompéu',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315240,
#   'NOME_MUNICIPIO': 'Poté',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315310,
#   'NOME_MUNICIPIO': 'Presidente Bernardes',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315340,
#   'NOME_MUNICIPIO': 'Presidente Olegário',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315410,
#   'NOME_MUNICIPIO': 'Recreio',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315430,
#   'NOME_MUNICIPIO': 'Resplendor',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315727,
#   'NOME_MUNICIPIO': 'Santa Bárbara do Monte Verde',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315800,
#   'NOME_MUNICIPIO': 'Santa Maria de Itabira',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315850,
#   'NOME_MUNICIPIO': 'Santana de Pirapama',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315920,
#   'NOME_MUNICIPIO': 'Santa Rita de Caldas',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316257,
#   'NOME_MUNICIPIO': 'São João do Manteninha',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316270,
#   'NOME_MUNICIPIO': 'São João do Paraíso',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316390,
#   'NOME_MUNICIPIO': 'São Pedro da União',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316450,
#   'NOME_MUNICIPIO': 'São Sebastião do Maranhão',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316610,
#   'NOME_MUNICIPIO': 'Senhora do Porto',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316820,
#   'NOME_MUNICIPIO': 'Tapiraí',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316970,
#   'NOME_MUNICIPIO': 'Turmalina',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 317030,
#   'NOME_MUNICIPIO': 'Umburatiba',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 317110,
#   'NOME_MUNICIPIO': 'Veríssimo',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 317190,
#   'NOME_MUNICIPIO': 'Virgolândia',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354625,
#   'NOME_MUNICIPIO': 'Santa Cruz da Esperança',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410337,
#   'NOME_MUNICIPIO': 'Brasilândia do Sul',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431190,
#   'NOME_MUNICIPIO': 'Marcelino Ramos',
#   'DIA': 1,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210130,
#   'NOME_MUNICIPIO': 'Bacuri',
#   'DIA': 2,
#   'MES': 1},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 240650,
#   'NOME_MUNICIPIO': 'Lagoa Nova',
#   'DIA': 2,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 250140,
#   'NOME_MUNICIPIO': 'Baía da Traição',
#   'DIA': 2,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 250650,
#   'NOME_MUNICIPIO': 'Gurjão',
#   'DIA': 2,
#   'MES': 1},
#  {'UF': 'AL',
#   'CODIGO_MUNICIPIO': 270460,
#   'NOME_MUNICIPIO': 'Maravilha',
#   'DIA': 2,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311220,
#   'NOME_MUNICIPIO': 'Capela Nova',
#   'DIA': 2,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150080,
#   'NOME_MUNICIPIO': 'Ananindeua',
#   'DIA': 3,
#   'MES': 1},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230710,
#   'NOME_MUNICIPIO': 'Jardim',
#   'DIA': 3,
#   'MES': 1},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 240350,
#   'NOME_MUNICIPIO': 'Espírito Santo',
#   'DIA': 4,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 250670,
#   'NOME_MUNICIPIO': 'Imaculada',
#   'DIA': 4,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 250830,
#   'NOME_MUNICIPIO': 'Lagoa Seca',
#   'DIA': 4,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421565,
#   'NOME_MUNICIPIO': 'Santa Rosa do Sul',
#   'DIA': 4,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421885,
#   'NOME_MUNICIPIO': 'União do Oeste',
#   'DIA': 4,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431740,
#   'NOME_MUNICIPIO': 'Santiago',
#   'DIA': 4,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431810,
#   'NOME_MUNICIPIO': 'São Francisco de Assis',
#   'DIA': 4,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421620,
#   'NOME_MUNICIPIO': 'São Francisco do Sul',
#   'DIA': 5,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 521900,
#   'NOME_MUNICIPIO': 'Sanclerlândia',
#   'DIA': 5,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150820,
#   'NOME_MUNICIPIO': 'Vigia',
#   'DIA': 6,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210770,
#   'NOME_MUNICIPIO': 'Paraibano',
#   'DIA': 6,
#   'MES': 1},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 260700,
#   'NOME_MUNICIPIO': 'Inajá',
#   'DIA': 6,
#   'MES': 1},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 261420,
#   'NOME_MUNICIPIO': 'Sirinhaém',
#   'DIA': 6,
#   'MES': 1},
#  {'UF': 'ES',
#   'CODIGO_MUNICIPIO': 320020,
#   'NOME_MUNICIPIO': 'Alegre',
#   'DIA': 6,
#   'MES': 1},
#  {'UF': 'RJ',
#   'CODIGO_MUNICIPIO': 330010,
#   'NOME_MUNICIPIO': 'Angra dos Reis',
#   'DIA': 6,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351385,
#   'NOME_MUNICIPIO': 'Dirce Reis',
#   'DIA': 6,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353190,
#   'NOME_MUNICIPIO': 'Morro Agudo',
#   'DIA': 6,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420460,
#   'NOME_MUNICIPIO': 'Criciúma',
#   'DIA': 6,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 521120,
#   'NOME_MUNICIPIO': 'Itapuranga',
#   'DIA': 6,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150600,
#   'NOME_MUNICIPIO': 'Prainha',
#   'DIA': 7,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 251220,
#   'NOME_MUNICIPIO': 'Prata',
#   'DIA': 7,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311330,
#   'NOME_MUNICIPIO': 'Carangola',
#   'DIA': 7,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314860,
#   'NOME_MUNICIPIO': 'Peçanha',
#   'DIA': 7,
#   'MES': 1},
#  {'UF': 'ES',
#   'CODIGO_MUNICIPIO': 320330,
#   'NOME_MUNICIPIO': 'Mantenópolis',
#   'DIA': 7,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431820,
#   'NOME_MUNICIPIO': 'São Francisco de Paula',
#   'DIA': 7,
#   'MES': 1},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 290515,
#   'NOME_MUNICIPIO': 'Caetanos',
#   'DIA': 8,
#   'MES': 1},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 292665,
#   'NOME_MUNICIPIO': 'Ribeirão do Largo',
#   'DIA': 8,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410322,
#   'NOME_MUNICIPIO': 'Bom Sucesso do Sul',
#   'DIA': 8,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 411450,
#   'NOME_MUNICIPIO': 'Manoel Ribas',
#   'DIA': 8,
#   'MES': 1},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 240615,
#   'NOME_MUNICIPIO': 'Jundiá',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 250700,
#   'NOME_MUNICIPIO': 'Itaporanga',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311580,
#   'NOME_MUNICIPIO': 'Centralina',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350745,
#   'NOME_MUNICIPIO': 'Borebi',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351495,
#   'NOME_MUNICIPIO': 'Embaúba',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351925,
#   'NOME_MUNICIPIO': 'Iaras',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 411325,
#   'NOME_MUNICIPIO': 'Laranjal',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420165,
#   'NOME_MUNICIPIO': 'Arvoredo',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420205,
#   'NOME_MUNICIPIO': 'Balneário Barra do Sul',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420215,
#   'NOME_MUNICIPIO': 'Belmonte',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420315,
#   'NOME_MUNICIPIO': 'Calmon',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420543,
#   'NOME_MUNICIPIO': 'Formosa do Sul',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420785,
#   'NOME_MUNICIPIO': 'Irati',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421165,
#   'NOME_MUNICIPIO': 'Novo Horizonte',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421185,
#   'NOME_MUNICIPIO': 'Ouro Verde',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421223,
#   'NOME_MUNICIPIO': 'Paraíso',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421555,
#   'NOME_MUNICIPIO': 'Santa Helena',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421715,
#   'NOME_MUNICIPIO': 'São Miguel da Boa Vista',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 522026,
#   'NOME_MUNICIPIO': 'São Miguel do Passa Quatro',
#   'DIA': 9,
#   'MES': 1},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170035,
#   'NOME_MUNICIPIO': 'Aliança do Tocantins',
#   'DIA': 10,
#   'MES': 1},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 261370,
#   'NOME_MUNICIPIO': 'São Lourenço da Mata',
#   'DIA': 10,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314120,
#   'NOME_MUNICIPIO': 'Matutina',
#   'DIA': 10,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316180,
#   'NOME_MUNICIPIO': 'São Gonçalo do Pará',
#   'DIA': 10,
#   'MES': 1},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170310,
#   'NOME_MUNICIPIO': 'Barrolândia',
#   'DIA': 11,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 251710,
#   'NOME_MUNICIPIO': 'Várzea',
#   'DIA': 11,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150140,
#   'NOME_MUNICIPIO': 'Belém',
#   'DIA': 12,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352120,
#   'NOME_MUNICIPIO': 'Iporanga',
#   'DIA': 12,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 211190,
#   'NOME_MUNICIPIO': 'Sucupira do Norte',
#   'DIA': 13,
#   'MES': 1},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 231335,
#   'NOME_MUNICIPIO': 'Tejuçuoca',
#   'DIA': 13,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 250380,
#   'NOME_MUNICIPIO': 'Caldas Brandão',
#   'DIA': 13,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 251110,
#   'NOME_MUNICIPIO': 'Pedra Lavrada',
#   'DIA': 13,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 310170,
#   'NOME_MUNICIPIO': 'Almenara',
#   'DIA': 13,
#   'MES': 1},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171800,
#   'NOME_MUNICIPIO': 'Porto Alegre do Tocantins',
#   'DIA': 14,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210750,
#   'NOME_MUNICIPIO': 'Paço do Lumiar',
#   'DIA': 14,
#   'MES': 1},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230425,
#   'NOME_MUNICIPIO': 'Cruz',
#   'DIA': 14,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352970,
#   'NOME_MUNICIPIO': 'Miguelópolis',
#   'DIA': 14,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420260,
#   'NOME_MUNICIPIO': 'Bom Retiro',
#   'DIA': 14,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 522068,
#   'NOME_MUNICIPIO': 'Simolândia',
#   'DIA': 14,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210600,
#   'NOME_MUNICIPIO': 'Lima Campos',
#   'DIA': 15,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 251060,
#   'NOME_MUNICIPIO': 'Ouro Velho',
#   'DIA': 15,
#   'MES': 1},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 292440,
#   'NOME_MUNICIPIO': 'Pilão Arcado',
#   'DIA': 15,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314620,
#   'NOME_MUNICIPIO': 'Ouro Verde de Minas',
#   'DIA': 15,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 317040,
#   'NOME_MUNICIPIO': 'Unaí',
#   'DIA': 15,
#   'MES': 1},
#  {'UF': 'RJ',
#   'CODIGO_MUNICIPIO': 330350,
#   'NOME_MUNICIPIO': 'Nova Iguaçu',
#   'DIA': 15,
#   'MES': 1},
#  {'UF': 'RJ',
#   'CODIGO_MUNICIPIO': 330370,
#   'NOME_MUNICIPIO': 'Paraíba do Sul',
#   'DIA': 15,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432280,
#   'NOME_MUNICIPIO': 'Veranópolis',
#   'DIA': 15,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 520055,
#   'NOME_MUNICIPIO': 'Alto Horizonte',
#   'DIA': 16,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 520505,
#   'NOME_MUNICIPIO': 'Castelândia',
#   'DIA': 16,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 521205,
#   'NOME_MUNICIPIO': 'Jesúpolis',
#   'DIA': 16,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 521487,
#   'NOME_MUNICIPIO': 'Nova Iguaçu de Goiás',
#   'DIA': 16,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 521839,
#   'NOME_MUNICIPIO': 'Professor Jamil',
#   'DIA': 16,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210095,
#   'NOME_MUNICIPIO': 'Arame',
#   'DIA': 17,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210760,
#   'NOME_MUNICIPIO': 'Palmeirândia',
#   'DIA': 17,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220720,
#   'NOME_MUNICIPIO': 'Padre Marcos',
#   'DIA': 17,
#   'MES': 1},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 240140,
#   'NOME_MUNICIPIO': 'Baía Formosa',
#   'DIA': 17,
#   'MES': 1},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 291700,
#   'NOME_MUNICIPIO': 'Itiúba',
#   'DIA': 17,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210420,
#   'NOME_MUNICIPIO': 'Fortuna',
#   'DIA': 18,
#   'MES': 1},
#  {'UF': 'RJ',
#   'CODIGO_MUNICIPIO': 330475,
#   'NOME_MUNICIPIO': 'São Francisco de Itabapoana',
#   'DIA': 18,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430710,
#   'NOME_MUNICIPIO': 'Herval',
#   'DIA': 18,
#   'MES': 1},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170384,
#   'NOME_MUNICIPIO': 'Campos Lindos',
#   'DIA': 19,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210490,
#   'NOME_MUNICIPIO': 'Guimarães',
#   'DIA': 19,
#   'MES': 1},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 240190,
#   'NOME_MUNICIPIO': 'Caiçara do Rio do Vento',
#   'DIA': 19,
#   'MES': 1},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 240960,
#   'NOME_MUNICIPIO': 'Pedra Preta',
#   'DIA': 19,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316880,
#   'NOME_MUNICIPIO': 'Tiradentes',
#   'DIA': 19,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354100,
#   'NOME_MUNICIPIO': 'Praia Grande',
#   'DIA': 19,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150520,
#   'NOME_MUNICIPIO': 'Oeiras do Pará',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150790,
#   'NOME_MUNICIPIO': 'Soure',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210040,
#   'NOME_MUNICIPIO': 'Altamira do Maranhão',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210520,
#   'NOME_MUNICIPIO': 'Igarapé Grande',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210810,
#   'NOME_MUNICIPIO': 'Paulo Ramos',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210890,
#   'NOME_MUNICIPIO': 'Poção de Pedras',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220553,
#   'NOME_MUNICIPIO': 'Jurema',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'AL',
#   'CODIGO_MUNICIPIO': 270720,
#   'NOME_MUNICIPIO': 'Poço das Trincheiras',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'SE',
#   'CODIGO_MUNICIPIO': 280730,
#   'NOME_MUNICIPIO': 'Telha',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311940,
#   'NOME_MUNICIPIO': 'Coronel Fabriciano',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312390,
#   'NOME_MUNICIPIO': 'Entre Rios de Minas',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314690,
#   'NOME_MUNICIPIO': 'Papagaios',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 317047,
#   'NOME_MUNICIPIO': 'Uruana de Minas',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'ES',
#   'CODIGO_MUNICIPIO': 320010,
#   'NOME_MUNICIPIO': 'Afonso Cláudio',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350770,
#   'NOME_MUNICIPIO': 'Braúna',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351070,
#   'NOME_MUNICIPIO': 'Cardoso',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352200,
#   'NOME_MUNICIPIO': 'Itaju',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353205,
#   'NOME_MUNICIPIO': 'Motuca',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353625,
#   'NOME_MUNICIPIO': 'Parisi',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353880,
#   'NOME_MUNICIPIO': 'Piraju',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354460,
#   'NOME_MUNICIPIO': 'Sabino',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354640,
#   'NOME_MUNICIPIO': 'Santa Cruz do Rio Pardo',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420960,
#   'NOME_MUNICIPIO': 'Lauro Müller',
#   'DIA': 20,
#   'MES': 1},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 241320,
#   'NOME_MUNICIPIO': 'Senador Georgino Avelino',
#   'DIA': 21,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 251560,
#   'NOME_MUNICIPIO': 'Serra da Raiz',
#   'DIA': 21,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 412665,
#   'NOME_MUNICIPIO': 'Sulina',
#   'DIA': 21,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421320,
#   'NOME_MUNICIPIO': 'Pomerode',
#   'DIA': 21,
#   'MES': 1},
#  {'UF': 'MT',
#   'CODIGO_MUNICIPIO': 510650,
#   'NOME_MUNICIPIO': 'Poconé',
#   'DIA': 21,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 520910,
#   'NOME_MUNICIPIO': 'Goiatuba',
#   'DIA': 21,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220170,
#   'NOME_MUNICIPIO': 'Bertolínia',
#   'DIA': 22,
#   'MES': 1},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230535,
#   'NOME_MUNICIPIO': 'Icapuí',
#   'DIA': 22,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355100,
#   'NOME_MUNICIPIO': 'São Vicente',
#   'DIA': 22,
#   'MES': 1},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 521850,
#   'NOME_MUNICIPIO': 'Quirinópolis',
#   'DIA': 22,
#   'MES': 1},
#  {'UF': 'AM',
#   'CODIGO_MUNICIPIO': 130400,
#   'NOME_MUNICIPIO': 'Silves',
#   'DIA': 23,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150550,
#   'NOME_MUNICIPIO': 'Paragominas',
#   'DIA': 23,
#   'MES': 1},
#  {'UF': 'AP',
#   'CODIGO_MUNICIPIO': 160040,
#   'NOME_MUNICIPIO': 'Mazagão',
#   'DIA': 23,
#   'MES': 1},
#  {'UF': 'SE',
#   'CODIGO_MUNICIPIO': 280110,
#   'NOME_MUNICIPIO': 'Canhoba',
#   'DIA': 23,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421030,
#   'NOME_MUNICIPIO': 'Major Vieira',
#   'DIA': 23,
#   'MES': 1},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421830,
#   'NOME_MUNICIPIO': 'Três Barras',
#   'DIA': 23,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430170,
#   'NOME_MUNICIPIO': 'Barão de Cotegipe',
#   'DIA': 23,
#   'MES': 1},
#  {'UF': 'AC',
#   'CODIGO_MUNICIPIO': 120080,
#   'NOME_MUNICIPIO': 'Porto Acre',
#   'DIA': 24,
#   'MES': 1},
#  {'UF': 'AM',
#   'CODIGO_MUNICIPIO': 130440,
#   'NOME_MUNICIPIO': 'Urucurituba',
#   'DIA': 24,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150580,
#   'NOME_MUNICIPIO': 'Portel',
#   'DIA': 24,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220455,
#   'NOME_MUNICIPIO': 'Guaribas',
#   'DIA': 24,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220995,
#   'NOME_MUNICIPIO': 'São João da Varjota',
#   'DIA': 24,
#   'MES': 1},
#  {'UF': 'ES',
#   'CODIGO_MUNICIPIO': 320030,
#   'NOME_MUNICIPIO': 'Alfredo Chaves',
#   'DIA': 24,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430470,
#   'NOME_MUNICIPIO': 'Carazinho',
#   'DIA': 24,
#   'MES': 1},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230090,
#   'NOME_MUNICIPIO': 'Apuiarés',
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230185,
#   'NOME_MUNICIPIO': 'Banabuiú',
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230550,
#   'NOME_MUNICIPIO': 'Iguatu',
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 231040,
#   'NOME_MUNICIPIO': 'Paramoti',
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314730,
#   'NOME_MUNICIPIO': 'Paraisópolis',
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350800,
#   'NOME_MUNICIPIO': 'Buri',
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351520,
#   'NOME_MUNICIPIO': "Estrela d'Oeste",
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355030,
#   'NOME_MUNICIPIO': 'São Paulo',
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355660,
#   'NOME_MUNICIPIO': 'Vera Cruz',
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410230,
#   'NOME_MUNICIPIO': 'Balsa Nova',
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410910,
#   'NOME_MUNICIPIO': 'Guaporema',
#   'DIA': 25,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210870,
#   'NOME_MUNICIPIO': 'Pio XII',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220045,
#   'NOME_MUNICIPIO': 'Alvorada do Gurguéia',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220117,
#   'NOME_MUNICIPIO': "Barra D'Alcântara",
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220155,
#   'NOME_MUNICIPIO': 'Bela Vista do Piauí',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220173,
#   'NOME_MUNICIPIO': 'Betânia do Piauí',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220177,
#   'NOME_MUNICIPIO': 'Boa Hora',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220194,
#   'NOME_MUNICIPIO': 'Boqueirão do Piauí',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220198,
#   'NOME_MUNICIPIO': 'Brejo do Piauí',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220213,
#   'NOME_MUNICIPIO': 'Campo Grande do Piauí',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220217,
#   'NOME_MUNICIPIO': 'Campo Largo do Piauí',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220245,
#   'NOME_MUNICIPIO': 'Capitão Gervásio Oliveira',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220255,
#   'NOME_MUNICIPIO': 'Caridade do Piauí',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220323,
#   'NOME_MUNICIPIO': 'Currais',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220327,
#   'NOME_MUNICIPIO': 'Curral Novo do Piauí',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220435,
#   'NOME_MUNICIPIO': 'Geminiano',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220465,
#   'NOME_MUNICIPIO': 'Ilha Grande',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220552,
#   'NOME_MUNICIPIO': 'Júlio Borges',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220557,
#   'NOME_MUNICIPIO': 'Lagoa de São Francisco',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220559,
#   'NOME_MUNICIPIO': 'Lagoa do Sítio',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220665,
#   'NOME_MUNICIPIO': 'Morro Cabeça no Tempo',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220675,
#   'NOME_MUNICIPIO': 'Nossa Senhora de Nazaré',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220695,
#   'NOME_MUNICIPIO': 'Novo Santo Antônio',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220735,
#   'NOME_MUNICIPIO': 'Pajeú do Piauí',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220755,
#   'NOME_MUNICIPIO': 'Paquetá',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220785,
#   'NOME_MUNICIPIO': 'Pavussu',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220795,
#   'NOME_MUNICIPIO': 'Nova Santa Rita',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220987,
#   'NOME_MUNICIPIO': 'São João da Fronteira',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 221062,
#   'NOME_MUNICIPIO': 'Sebastião Barros',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 221063,
#   'NOME_MUNICIPIO': 'Sebastião Leal',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 291490,
#   'NOME_MUNICIPIO': 'Itacaré',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'ES',
#   'CODIGO_MUNICIPIO': 320390,
#   'NOME_MUNICIPIO': 'Nova Venécia',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354850,
#   'NOME_MUNICIPIO': 'Santos',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410765,
#   'NOME_MUNICIPIO': 'Fazenda Rio Grande',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431140,
#   'NOME_MUNICIPIO': 'Lajeado',
#   'DIA': 26,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314930,
#   'NOME_MUNICIPIO': 'Pedro Leopoldo',
#   'DIA': 27,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150240,
#   'NOME_MUNICIPIO': 'Castanhal',
#   'DIA': 28,
#   'MES': 1},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 251240,
#   'NOME_MUNICIPIO': 'Puxinanã',
#   'DIA': 28,
#   'MES': 1},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 291430,
#   'NOME_MUNICIPIO': 'Iramaia',
#   'DIA': 28,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410140,
#   'NOME_MUNICIPIO': 'Apucarana',
#   'DIA': 28,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 411960,
#   'NOME_MUNICIPIO': 'Pitanga',
#   'DIA': 28,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 412240,
#   'NOME_MUNICIPIO': 'Rolândia',
#   'DIA': 28,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430900,
#   'NOME_MUNICIPIO': 'Giruá',
#   'DIA': 28,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431790,
#   'NOME_MUNICIPIO': 'Santo Cristo',
#   'DIA': 28,
#   'MES': 1},
#  {'UF': 'MT',
#   'CODIGO_MUNICIPIO': 510757,
#   'NOME_MUNICIPIO': 'Rondolândia',
#   'DIA': 28,
#   'MES': 1},
#  {'UF': 'MT',
#   'CODIGO_MUNICIPIO': 510779,
#   'NOME_MUNICIPIO': 'Santo Antônio do Leste',
#   'DIA': 28,
#   'MES': 1},
#  {'UF': 'AM',
#   'CODIGO_MUNICIPIO': 130060,
#   'NOME_MUNICIPIO': 'Benjamin Constant',
#   'DIA': 29,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150555,
#   'NOME_MUNICIPIO': "Pau D'Arco",
#   'DIA': 29,
#   'MES': 1},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220779,
#   'NOME_MUNICIPIO': "Pau D'Arco do Piauí",
#   'DIA': 29,
#   'MES': 1},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 240750,
#   'NOME_MUNICIPIO': 'Maxaranguape',
#   'DIA': 29,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316710,
#   'NOME_MUNICIPIO': 'Serro',
#   'DIA': 29,
#   'MES': 1},
#  {'UF': 'ES',
#   'CODIGO_MUNICIPIO': 320050,
#   'NOME_MUNICIPIO': 'Apiacá',
#   'DIA': 29,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 411950,
#   'NOME_MUNICIPIO': 'Piraquara',
#   'DIA': 29,
#   'MES': 1},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210680,
#   'NOME_MUNICIPIO': 'Mirinzal',
#   'DIA': 30,
#   'MES': 1},
#  {'UF': 'SE',
#   'CODIGO_MUNICIPIO': 280270,
#   'NOME_MUNICIPIO': 'Ilha das Flores',
#   'DIA': 30,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312770,
#   'NOME_MUNICIPIO': 'Governador Valadares',
#   'DIA': 30,
#   'MES': 1},
#  {'UF': 'AM',
#   'CODIGO_MUNICIPIO': 130068,
#   'NOME_MUNICIPIO': 'Boa Vista do Ramos',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'AM',
#   'CODIGO_MUNICIPIO': 130150,
#   'NOME_MUNICIPIO': 'Envira',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'AM',
#   'CODIGO_MUNICIPIO': 130300,
#   'NOME_MUNICIPIO': 'Nhamundá',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150650,
#   'NOME_MUNICIPIO': 'Santa Izabel do Pará',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 290205,
#   'NOME_MUNICIPIO': 'Araçás',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 291820,
#   'NOME_MUNICIPIO': 'Jiquiriçá',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315600,
#   'NOME_MUNICIPIO': 'Rio Vermelho',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316840,
#   'NOME_MUNICIPIO': 'Tarumirim',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'ES',
#   'CODIGO_MUNICIPIO': 320305,
#   'NOME_MUNICIPIO': 'Jaguaré',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350510,
#   'NOME_MUNICIPIO': 'Barbosa',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 411573,
#   'NOME_MUNICIPIO': 'Mato Rico',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430240,
#   'NOME_MUNICIPIO': 'Bom Retiro do Sul',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430390,
#   'NOME_MUNICIPIO': 'Campo Bom',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431670,
#   'NOME_MUNICIPIO': 'Santa Bárbara do Sul',
#   'DIA': 31,
#   'MES': 1},
#  {'UF': 'AM',
#   'CODIGO_MUNICIPIO': 130195,
#   'NOME_MUNICIPIO': 'Itamarati',
#   'DIA': 1,
#   'MES': 2},
#  {'UF': 'AM',
#   'CODIGO_MUNICIPIO': 130406,
#   'NOME_MUNICIPIO': 'Tabatinga',
#   'DIA': 1,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 172208,
#   'NOME_MUNICIPIO': 'Wanderlândia',
#   'DIA': 1,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 231135,
#   'NOME_MUNICIPIO': 'Quixelô',
#   'DIA': 1,
#   'MES': 2},
#  {'UF': 'AL',
#   'CODIGO_MUNICIPIO': 270040,
#   'NOME_MUNICIPIO': 'Atalaia',
#   'DIA': 1,
#   'MES': 2},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314465,
#   'NOME_MUNICIPIO': 'Ninheira',
#   'DIA': 1,
#   'MES': 2},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410725,
#   'NOME_MUNICIPIO': 'Douradina',
#   'DIA': 1,
#   'MES': 2},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 411605,
#   'NOME_MUNICIPIO': 'Missal',
#   'DIA': 1,
#   'MES': 2},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 411725,
#   'NOME_MUNICIPIO': 'Nova Prata do Iguaçu',
#   'DIA': 1,
#   'MES': 2},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 521483,
#   'NOME_MUNICIPIO': 'Nova Crixás',
#   'DIA': 1,
#   'MES': 2},
#  {'UF': 'PB',
#   'CODIGO_MUNICIPIO': 250730,
#   'NOME_MUNICIPIO': 'Jacaraú',
#   'DIA': 2,
#   'MES': 2},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 261030,
#   'NOME_MUNICIPIO': 'Paranatama',
#   'DIA': 2,
#   'MES': 2},
#  {'UF': 'AL',
#   'CODIGO_MUNICIPIO': 270600,
#   'NOME_MUNICIPIO': 'Olivença',
#   'DIA': 2,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352390,
#   'NOME_MUNICIPIO': 'Itu',
#   'DIA': 2,
#   'MES': 2},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 412690,
#   'NOME_MUNICIPIO': 'Tapira',
#   'DIA': 2,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421960,
#   'NOME_MUNICIPIO': 'Xavantina',
#   'DIA': 2,
#   'MES': 2},
#  {'UF': 'AL',
#   'CODIGO_MUNICIPIO': 270375,
#   'NOME_MUNICIPIO': 'Jequiá da Praia',
#   'DIA': 3,
#   'MES': 2},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312810,
#   'NOME_MUNICIPIO': 'Guapé',
#   'DIA': 3,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421890,
#   'NOME_MUNICIPIO': 'Urubici',
#   'DIA': 3,
#   'MES': 2},
#  {'UF': 'AP',
#   'CODIGO_MUNICIPIO': 160030,
#   'NOME_MUNICIPIO': 'Macapá',
#   'DIA': 4,
#   'MES': 2},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 260600,
#   'NOME_MUNICIPIO': 'Garanhuns',
#   'DIA': 4,
#   'MES': 2},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 260765,
#   'NOME_MUNICIPIO': 'Itambé',
#   'DIA': 4,
#   'MES': 2},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 261060,
#   'NOME_MUNICIPIO': 'Paudalho',
#   'DIA': 4,
#   'MES': 2},
#  {'UF': 'AL',
#   'CODIGO_MUNICIPIO': 270350,
#   'NOME_MUNICIPIO': 'Jacuípe',
#   'DIA': 4,
#   'MES': 2},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 293120,
#   'NOME_MUNICIPIO': 'Taperoá',
#   'DIA': 4,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351410,
#   'NOME_MUNICIPIO': 'Dois Córregos',
#   'DIA': 4,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421390,
#   'NOME_MUNICIPIO': 'Presidente Castello Branco',
#   'DIA': 4,
#   'MES': 2},
#  {'UF': 'PI',
#   'CODIGO_MUNICIPIO': 220530,
#   'NOME_MUNICIPIO': 'Jerumenha',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230075,
#   'NOME_MUNICIPIO': 'Amontada',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230435,
#   'NOME_MUNICIPIO': 'Forquilha',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230655,
#   'NOME_MUNICIPIO': 'Itarema',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230800,
#   'NOME_MUNICIPIO': 'Massapê',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230835,
#   'NOME_MUNICIPIO': 'Milhã',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 231025,
#   'NOME_MUNICIPIO': 'Paraipaba',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 231375,
#   'NOME_MUNICIPIO': 'Umirim',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 231395,
#   'NOME_MUNICIPIO': 'Varjota',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'SE',
#   'CODIGO_MUNICIPIO': 280260,
#   'NOME_MUNICIPIO': 'Gracho Cardoso',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 310230,
#   'NOME_MUNICIPIO': 'Alvinópolis',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 314480,
#   'NOME_MUNICIPIO': 'Nova Lima',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410580,
#   'NOME_MUNICIPIO': 'Colombo',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'MT',
#   'CODIGO_MUNICIPIO': 510130,
#   'NOME_MUNICIPIO': 'Arenápolis',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'MT',
#   'CODIGO_MUNICIPIO': 510600,
#   'NOME_MUNICIPIO': 'Nortelândia',
#   'DIA': 5,
#   'MES': 2},
#  {'UF': 'SE',
#   'CODIGO_MUNICIPIO': 280760,
#   'NOME_MUNICIPIO': 'Umbaúba',
#   'DIA': 6,
#   'MES': 2},
#  {'UF': 'RJ',
#   'CODIGO_MUNICIPIO': 330020,
#   'NOME_MUNICIPIO': 'Araruama',
#   'DIA': 6,
#   'MES': 2},
#  {'UF': 'SE',
#   'CODIGO_MUNICIPIO': 280570,
#   'NOME_MUNICIPIO': 'Propriá',
#   'DIA': 7,
#   'MES': 2},
#  {'UF': 'MS',
#   'CODIGO_MUNICIPIO': 500020,
#   'NOME_MUNICIPIO': 'Água Clara',
#   'DIA': 8,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230480,
#   'NOME_MUNICIPIO': 'Granjeiro',
#   'DIA': 9,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170382,
#   'NOME_MUNICIPIO': 'Cachoeirinha',
#   'DIA': 10,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170740,
#   'NOME_MUNICIPIO': 'Esperantina',
#   'DIA': 10,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171195,
#   'NOME_MUNICIPIO': 'Lagoa do Tocantins',
#   'DIA': 10,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171280,
#   'NOME_MUNICIPIO': 'Maurilândia do Tocantins',
#   'DIA': 10,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171380,
#   'NOME_MUNICIPIO': 'Palmeiras do Tocantins',
#   'DIA': 10,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171630,
#   'NOME_MUNICIPIO': "Pau D'Arco",
#   'DIA': 10,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 172010,
#   'NOME_MUNICIPIO': 'São Bento do Tocantins',
#   'DIA': 10,
#   'MES': 2},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 211160,
#   'NOME_MUNICIPIO': 'São Raimundo das Mangabeiras',
#   'DIA': 10,
#   'MES': 2},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 241410,
#   'NOME_MUNICIPIO': 'Tenente Ananias',
#   'DIA': 10,
#   'MES': 2},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316890,
#   'NOME_MUNICIPIO': 'Tiros',
#   'DIA': 10,
#   'MES': 2},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150610,
#   'NOME_MUNICIPIO': 'Primavera',
#   'DIA': 11,
#   'MES': 2},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210030,
#   'NOME_MUNICIPIO': 'Aldeias Altas',
#   'DIA': 11,
#   'MES': 2},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410180,
#   'NOME_MUNICIPIO': 'Araucária',
#   'DIA': 11,
#   'MES': 2},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430080,
#   'NOME_MUNICIPIO': 'Antônio Prado',
#   'DIA': 11,
#   'MES': 2},
#  {'UF': 'PA',
#   'CODIGO_MUNICIPIO': 150619,
#   'NOME_MUNICIPIO': 'Rurópolis',
#   'DIA': 12,
#   'MES': 2},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312900,
#   'NOME_MUNICIPIO': 'Guiricema',
#   'DIA': 12,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421780,
#   'NOME_MUNICIPIO': 'Taió',
#   'DIA': 12,
#   'MES': 2},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430800,
#   'NOME_MUNICIPIO': 'Faxinal do Soturno',
#   'DIA': 12,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110007,
#   'NOME_MUNICIPIO': 'Corumbiara',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110026,
#   'NOME_MUNICIPIO': 'Rio Crespo',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110040,
#   'NOME_MUNICIPIO': 'Alto Paraíso',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110050,
#   'NOME_MUNICIPIO': 'Novo Horizonte do Oeste',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110070,
#   'NOME_MUNICIPIO': 'Campo Novo de Rondônia',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110080,
#   'NOME_MUNICIPIO': 'Candeias do Jamari',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110090,
#   'NOME_MUNICIPIO': 'Castanheiras',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110100,
#   'NOME_MUNICIPIO': 'Governador Jorge Teixeira',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110110,
#   'NOME_MUNICIPIO': 'Itapuã do Oeste',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110120,
#   'NOME_MUNICIPIO': 'Ministro Andreazza',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110130,
#   'NOME_MUNICIPIO': 'Mirante da Serra',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110140,
#   'NOME_MUNICIPIO': 'Monte Negro',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110150,
#   'NOME_MUNICIPIO': 'Seringueiras',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110160,
#   'NOME_MUNICIPIO': 'Theobroma',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110170,
#   'NOME_MUNICIPIO': 'Urupá',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210930,
#   'NOME_MUNICIPIO': 'Presidente Vargas',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'CE',
#   'CODIGO_MUNICIPIO': 230100,
#   'NOME_MUNICIPIO': 'Aquiraz',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 292450,
#   'NOME_MUNICIPIO': 'Pindaí',
#   'DIA': 13,
#   'MES': 2},
#  {'UF': 'AL',
#   'CODIGO_MUNICIPIO': 270240,
#   'NOME_MUNICIPIO': 'Delmiro Gouveia',
#   'DIA': 14,
#   'MES': 2},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 311000,
#   'NOME_MUNICIPIO': 'Caeté',
#   'DIA': 14,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420840,
#   'NOME_MUNICIPIO': 'Itapiranga',
#   'DIA': 14,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420850,
#   'NOME_MUNICIPIO': 'Ituporanga',
#   'DIA': 14,
#   'MES': 2},
#  {'UF': 'MA',
#   'CODIGO_MUNICIPIO': 210650,
#   'NOME_MUNICIPIO': 'Matinha',
#   'DIA': 15,
#   'MES': 2},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410640,
#   'NOME_MUNICIPIO': 'Cornélio Procópio',
#   'DIA': 15,
#   'MES': 2},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 412510,
#   'NOME_MUNICIPIO': 'São João do Triunfo',
#   'DIA': 15,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421720,
#   'NOME_MUNICIPIO': 'São Miguel do Oeste',
#   'DIA': 15,
#   'MES': 2},
#  {'UF': 'MT',
#   'CODIGO_MUNICIPIO': 510270,
#   'NOME_MUNICIPIO': 'Canarana',
#   'DIA': 15,
#   'MES': 2},
#  {'UF': 'SE',
#   'CODIGO_MUNICIPIO': 280630,
#   'NOME_MUNICIPIO': 'Santa Luzia do Itanhy',
#   'DIA': 16,
#   'MES': 2},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 315390,
#   'NOME_MUNICIPIO': 'Raposos',
#   'DIA': 16,
#   'MES': 2},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430010,
#   'NOME_MUNICIPIO': 'Agudo',
#   'DIA': 16,
#   'MES': 2},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430140,
#   'NOME_MUNICIPIO': 'Arvorezinha',
#   'DIA': 16,
#   'MES': 2},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 316230,
#   'NOME_MUNICIPIO': 'São João da Mata',
#   'DIA': 17,
#   'MES': 2},
#  {'UF': 'ES',
#   'CODIGO_MUNICIPIO': 320270,
#   'NOME_MUNICIPIO': 'Itaguaçu',
#   'DIA': 17,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420390,
#   'NOME_MUNICIPIO': 'Capinzal',
#   'DIA': 17,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421920,
#   'NOME_MUNICIPIO': 'Vidal Ramos',
#   'DIA': 17,
#   'MES': 2},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430190,
#   'NOME_MUNICIPIO': 'Barra do Ribeiro',
#   'DIA': 17,
#   'MES': 2},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431970,
#   'NOME_MUNICIPIO': 'São Valentim',
#   'DIA': 17,
#   'MES': 2},
#  {'UF': 'AM',
#   'CODIGO_MUNICIPIO': 130180,
#   'NOME_MUNICIPIO': 'Ipixuna',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 240820,
#   'NOME_MUNICIPIO': 'Nísia Floresta',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350460,
#   'NOME_MUNICIPIO': 'Bady Bassitt',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350920,
#   'NOME_MUNICIPIO': 'Cajamar',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351010,
#   'NOME_MUNICIPIO': 'Cândido Rodrigues',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351090,
#   'NOME_MUNICIPIO': 'Cássia dos Coqueiros',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351210,
#   'NOME_MUNICIPIO': 'Colômbia',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351500,
#   'NOME_MUNICIPIO': 'Embu das Artes',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352250,
#   'NOME_MUNICIPIO': 'Itapevi',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352770,
#   'NOME_MUNICIPIO': 'Luiziânia',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353610,
#   'NOME_MUNICIPIO': 'Pardinho',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353760,
#   'NOME_MUNICIPIO': 'Peruíbe',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354470,
#   'NOME_MUNICIPIO': 'Sagres',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354510,
#   'NOME_MUNICIPIO': 'Salmourão',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355120,
#   'NOME_MUNICIPIO': 'Sarutaiá',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355300,
#   'NOME_MUNICIPIO': 'Taguaí',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 412300,
#   'NOME_MUNICIPIO': 'Salto do Lontra',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421310,
#   'NOME_MUNICIPIO': 'Piratuba',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431580,
#   'NOME_MUNICIPIO': 'Roca Sales',
#   'DIA': 18,
#   'MES': 2},
#  {'UF': 'SE',
#   'CODIGO_MUNICIPIO': 280560,
#   'NOME_MUNICIPIO': 'Porto da Folha',
#   'DIA': 19,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353440,
#   'NOME_MUNICIPIO': 'Osasco',
#   'DIA': 19,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355190,
#   'NOME_MUNICIPIO': 'Severínia',
#   'DIA': 19,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355280,
#   'NOME_MUNICIPIO': 'Taboão da Serra',
#   'DIA': 19,
#   'MES': 2},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355350,
#   'NOME_MUNICIPIO': 'Tapiraí',
#   'DIA': 19,
#   'MES': 2},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421790,
#   'NOME_MUNICIPIO': 'Tangará',
#   'DIA': 19,
#   'MES': 2},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431560,
#   'NOME_MUNICIPIO': 'Rio Grande',
#   'DIA': 19,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170105,
#   'NOME_MUNICIPIO': 'Angico',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170215,
#   'NOME_MUNICIPIO': 'Araguanã',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170330,
#   'NOME_MUNICIPIO': 'Bom Jesus do Tocantins',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170360,
#   'NOME_MUNICIPIO': 'Brasilândia do Tocantins',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170386,
#   'NOME_MUNICIPIO': 'Cariri do Tocantins',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170388,
#   'NOME_MUNICIPIO': 'Carmolândia',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170389,
#   'NOME_MUNICIPIO': 'Carrasco Bonito',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170410,
#   'NOME_MUNICIPIO': 'Centenário',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 170825,
#   'NOME_MUNICIPIO': 'Tabocão',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171190,
#   'NOME_MUNICIPIO': 'Lagoa da Confusão',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171270,
#   'NOME_MUNICIPIO': 'Mateiros',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171525,
#   'NOME_MUNICIPIO': 'Novo Jardim',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171570,
#   'NOME_MUNICIPIO': 'Palmeirante',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171720,
#   'NOME_MUNICIPIO': 'Piraquê',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171855,
#   'NOME_MUNICIPIO': 'Riachinho',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 171865,
#   'NOME_MUNICIPIO': 'Rio da Conceição',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 172015,
#   'NOME_MUNICIPIO': 'São Félix do Tocantins',
#   'DIA': 20,
#   'MES': 2},
#  {'UF': 'TO',
#   'CODIGO_MUNICIPIO': 172020,
#   'NOME_MUNICIPIO': 'São Miguel do Tocantins',
#   'DIA': 20,
# ...
#   'NOME_MUNICIPIO': 'Flora Rica',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352560,
#   'NOME_MUNICIPIO': 'João Ramalho',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352960,
#   'NOME_MUNICIPIO': 'Meridiano',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353540,
#   'NOME_MUNICIPIO': 'Panorama',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354330,
#   'NOME_MUNICIPIO': 'Ribeirão Pires',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354970,
#   'NOME_MUNICIPIO': 'São José do Rio Pardo',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354980,
#   'NOME_MUNICIPIO': 'São José do Rio Preto',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355310,
#   'NOME_MUNICIPIO': 'Taiaçu',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355695,
#   'NOME_MUNICIPIO': 'Vitória Brasil',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410490,
#   'NOME_MUNICIPIO': 'Castro',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 412215,
#   'NOME_MUNICIPIO': 'Rio Bonito do Iguaçu',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 412550,
#   'NOME_MUNICIPIO': 'São José dos Pinhais',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 412627,
#   'NOME_MUNICIPIO': 'Saudade do Iguaçu',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421660,
#   'NOME_MUNICIPIO': 'São José',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431360,
#   'NOME_MUNICIPIO': 'Paim Filho',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'MS',
#   'CODIGO_MUNICIPIO': 500410,
#   'NOME_MUNICIPIO': 'Guia Lopes da Laguna',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'MS',
#   'CODIGO_MUNICIPIO': 500710,
#   'NOME_MUNICIPIO': 'Ribas do Rio Pardo',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'MT',
#   'CODIGO_MUNICIPIO': 510380,
#   'NOME_MUNICIPIO': "Figueirópolis D'Oeste",
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'MT',
#   'CODIGO_MUNICIPIO': 510550,
#   'NOME_MUNICIPIO': 'Vila Bela da Santíssima Trindade',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'MT',
#   'CODIGO_MUNICIPIO': 510730,
#   'NOME_MUNICIPIO': 'São José do Rio Claro',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 521000,
#   'NOME_MUNICIPIO': 'Inhumas',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 521460,
#   'NOME_MUNICIPIO': 'Niquelândia',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'GO',
#   'CODIGO_MUNICIPIO': 521760,
#   'NOME_MUNICIPIO': 'Planaltina',
#   'DIA': 19,
#   'MES': 3},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 240330,
#   'NOME_MUNICIPIO': 'Encanto',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'PE',
#   'CODIGO_MUNICIPIO': 261600,
#   'NOME_MUNICIPIO': 'Venturosa',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 292405,
#   'NOME_MUNICIPIO': 'Pé de Serra',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 312570,
#   'NOME_MUNICIPIO': 'Felixlândia',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'ES',
#   'CODIGO_MUNICIPIO': 320503,
#   'NOME_MUNICIPIO': 'Vargem Alta',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353830,
#   'NOME_MUNICIPIO': 'Piquerobi',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 410600,
#   'NOME_MUNICIPIO': 'Congonhinhas',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 411915,
#   'NOME_MUNICIPIO': 'Pinhais',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'PR',
#   'CODIGO_MUNICIPIO': 412135,
#   'NOME_MUNICIPIO': "Rancho Alegre D'Oeste",
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420080,
#   'NOME_MUNICIPIO': 'Anchieta',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 420895,
#   'NOME_MUNICIPIO': 'Jardinópolis',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'SC',
#   'CODIGO_MUNICIPIO': 421880,
#   'NOME_MUNICIPIO': 'Turvo',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430057,
#   'NOME_MUNICIPIO': 'Alto Feliz',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430064,
#   'NOME_MUNICIPIO': 'Ametista do Sul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430085,
#   'NOME_MUNICIPIO': 'Arambaré',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430175,
#   'NOME_MUNICIPIO': 'Barão do Triunfo',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430185,
#   'NOME_MUNICIPIO': 'Barra do Guarita',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430192,
#   'NOME_MUNICIPIO': 'Barra do Rio Azul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430215,
#   'NOME_MUNICIPIO': 'Boa Vista das Missões',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430237,
#   'NOME_MUNICIPIO': 'Bom Progresso',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430367,
#   'NOME_MUNICIPIO': 'Campestre da Serra',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430469,
#   'NOME_MUNICIPIO': 'Capitão',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430485,
#   'NOME_MUNICIPIO': 'Carlos Gomes',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430511,
#   'NOME_MUNICIPIO': 'Centenário',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430537,
#   'NOME_MUNICIPIO': 'Charrua',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430558,
#   'NOME_MUNICIPIO': 'Colinas',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430585,
#   'NOME_MUNICIPIO': 'Coqueiros do Sul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430587,
#   'NOME_MUNICIPIO': 'Coronel Barros',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430597,
#   'NOME_MUNICIPIO': 'Coxilha',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430632,
#   'NOME_MUNICIPIO': 'Derrubadas',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430642,
#   'NOME_MUNICIPIO': 'Dois Irmãos das Missões',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430692,
#   'NOME_MUNICIPIO': 'Engenho Velho',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430865,
#   'NOME_MUNICIPIO': 'Garruchos',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 430885,
#   'NOME_MUNICIPIO': 'Gentil',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431041,
#   'NOME_MUNICIPIO': 'Inhacorá',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431057,
#   'NOME_MUNICIPIO': 'Itapuca',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431127,
#   'NOME_MUNICIPIO': 'Lagoa dos Três Cantos',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431142,
#   'NOME_MUNICIPIO': 'Lajeado do Bugre',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431164,
#   'NOME_MUNICIPIO': 'Linha Nova',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431175,
#   'NOME_MUNICIPIO': 'Manoel Viana',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431177,
#   'NOME_MUNICIPIO': 'Maquiné',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431179,
#   'NOME_MUNICIPIO': 'Maratá',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431215,
#   'NOME_MUNICIPIO': 'Mato Leitão',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431225,
#   'NOME_MUNICIPIO': 'Minas do Leão',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431238,
#   'NOME_MUNICIPIO': 'Monte Belo do Sul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431242,
#   'NOME_MUNICIPIO': 'Mormaço',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431244,
#   'NOME_MUNICIPIO': 'Morrinhos do Sul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431247,
#   'NOME_MUNICIPIO': 'Morro Reuter',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431262,
#   'NOME_MUNICIPIO': 'Muliterno',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431267,
#   'NOME_MUNICIPIO': 'Nicolau Vergueiro',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431295,
#   'NOME_MUNICIPIO': 'Nova Boa Vista',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431308,
#   'NOME_MUNICIPIO': 'Nova Pádua',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431337,
#   'NOME_MUNICIPIO': 'Nova Santa Rita',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431342,
#   'NOME_MUNICIPIO': 'Novo Machado',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431344,
#   'NOME_MUNICIPIO': 'Novo Tiradentes',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431349,
#   'NOME_MUNICIPIO': 'Novo Barreiro',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431403,
#   'NOME_MUNICIPIO': 'Pareci Novo',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431407,
#   'NOME_MUNICIPIO': 'Passo do Sobrado',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431442,
#   'NOME_MUNICIPIO': 'Picada Café',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431447,
#   'NOME_MUNICIPIO': 'Pinhal Grande',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431449,
#   'NOME_MUNICIPIO': 'Pinheirinho do Vale',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431477,
#   'NOME_MUNICIPIO': 'Pontão',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431478,
#   'NOME_MUNICIPIO': 'Ponte Preta',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431505,
#   'NOME_MUNICIPIO': 'Porto Mauá',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431507,
#   'NOME_MUNICIPIO': 'Porto Vera Cruz',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431514,
#   'NOME_MUNICIPIO': 'Presidente Lucena',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431532,
#   'NOME_MUNICIPIO': 'Quevedos',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431555,
#   'NOME_MUNICIPIO': 'Rio dos Índios',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431642,
#   'NOME_MUNICIPIO': 'Sagrada Família',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431675,
#   'NOME_MUNICIPIO': 'Santa Clara do Sul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431725,
#   'NOME_MUNICIPIO': 'Santa Tereza',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431755,
#   'NOME_MUNICIPIO': 'Santo Antônio do Palma',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431775,
#   'NOME_MUNICIPIO': 'Santo Antônio do Planalto',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431843,
#   'NOME_MUNICIPIO': 'São João do Polêsine',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431845,
#   'NOME_MUNICIPIO': 'São José das Missões',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431849,
#   'NOME_MUNICIPIO': 'São José do Inhacorá',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431862,
#   'NOME_MUNICIPIO': 'São José dos Ausentes',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431912,
#   'NOME_MUNICIPIO': 'São Martinho da Serra',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431935,
#   'NOME_MUNICIPIO': 'São Pedro da Serra',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431937,
#   'NOME_MUNICIPIO': 'São Pedro do Butiá',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431971,
#   'NOME_MUNICIPIO': 'São Valentim do Sul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 431973,
#   'NOME_MUNICIPIO': 'São Valério do Sul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432035,
#   'NOME_MUNICIPIO': 'Sentinela do Sul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432045,
#   'NOME_MUNICIPIO': 'Sério',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432067,
#   'NOME_MUNICIPIO': 'Sinimbu',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432147,
#   'NOME_MUNICIPIO': 'Tiradentes do Sul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432162,
#   'NOME_MUNICIPIO': 'Travesseiro',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432183,
#   'NOME_MUNICIPIO': 'Três Forquilhas',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432235,
#   'NOME_MUNICIPIO': 'União da Serra',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432254,
#   'NOME_MUNICIPIO': 'Vale Real',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432345,
#   'NOME_MUNICIPIO': 'Vila Nova do Sul',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RS',
#   'CODIGO_MUNICIPIO': 432375,
#   'NOME_MUNICIPIO': 'Vitória das Missões',
#   'DIA': 20,
#   'MES': 3},
#  {'UF': 'RO',
#   'CODIGO_MUNICIPIO': 110034,
#   'NOME_MUNICIPIO': "Alvorada D'Oeste",
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'RN',
#   'CODIGO_MUNICIPIO': 240180,
#   'NOME_MUNICIPIO': 'Brejinho',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SE',
#   'CODIGO_MUNICIPIO': 280067,
#   'NOME_MUNICIPIO': 'Boquim',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 292150,
#   'NOME_MUNICIPIO': 'Monte Santo',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'BA',
#   'CODIGO_MUNICIPIO': 293190,
#   'NOME_MUNICIPIO': 'Tucano',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'MG',
#   'CODIGO_MUNICIPIO': 313390,
#   'NOME_MUNICIPIO': 'Itaverava',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350170,
#   'NOME_MUNICIPIO': 'Américo Brasiliense',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350500,
#   'NOME_MUNICIPIO': 'Barão de Antonina',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350540,
#   'NOME_MUNICIPIO': 'Barra do Turvo',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350740,
#   'NOME_MUNICIPIO': 'Borborema',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 350960,
#   'NOME_MUNICIPIO': 'Campo Limpo Paulista',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351260,
#   'NOME_MUNICIPIO': 'Coronel Macedo',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351460,
#   'NOME_MUNICIPIO': 'Dumont',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351530,
#   'NOME_MUNICIPIO': 'Estrela do Norte',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 351630,
#   'NOME_MUNICIPIO': 'Francisco Morato',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352100,
#   'NOME_MUNICIPIO': 'Iperó',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352110,
#   'NOME_MUNICIPIO': 'Ipeúna',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352300,
#   'NOME_MUNICIPIO': 'Itapura',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352400,
#   'NOME_MUNICIPIO': 'Itupeva',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352700,
#   'NOME_MUNICIPIO': 'Lindóia',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 352730,
#   'NOME_MUNICIPIO': 'Louveira',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353000,
#   'NOME_MUNICIPIO': 'Mira Estrela',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353090,
#   'NOME_MUNICIPIO': 'Mombuca',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353100,
#   'NOME_MUNICIPIO': 'Monções',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353220,
#   'NOME_MUNICIPIO': 'Narandiba',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353320,
#   'NOME_MUNICIPIO': 'Nova Independência',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353420,
#   'NOME_MUNICIPIO': 'Orindiúva',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 353810,
#   'NOME_MUNICIPIO': 'Pindorama',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354080,
#   'NOME_MUNICIPIO': 'Potirendaba',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354210,
#   'NOME_MUNICIPIO': 'Rafard',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354320,
#   'NOME_MUNICIPIO': 'Ribeirão do Sul',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354430,
#   'NOME_MUNICIPIO': 'Roseira',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354650,
#   'NOME_MUNICIPIO': 'Santa Ernestina',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 354720,
#   'NOME_MUNICIPIO': 'Santana da Ponte Pensa',
#   'DIA': 21,
#   'MES': 3},
#  {'UF': 'SP',
#   'CODIGO_MUNICIPIO': 355390,
#   'NOME_MUNICIPIO': 'Tarabai',
#   'DIA': 21,
#   'MES': 3},
#  ...]

# %%
df0 = copy(estados)
df0.head()
# Out:
#   SIGLA    ESTADO     CAPITAL    REGIAO
# 0    AC      Acre  Rio Branco     NORTE
# 1    AL   Alagoas      Maceió  NORDESTE
# 2    AP     Amapá      Macapá     NORTE
# 3    AM  Amazonas      Manaus     NORTE
# 4    BA     Bahia    Salvador  NORDESTE

# %%
df0.columns = df0.columns.str.casefold()
df0.columns
# Out:
# Index(['sigla', 'estado', 'capital', 'regiao'], dtype='object')

# %%
df0.head()
# Out:
#   sigla    estado     capital    regiao
# 0    AC      Acre  Rio Branco     NORTE
# 1    AL   Alagoas      Maceió  NORDESTE
# 2    AP     Amapá      Macapá     NORTE
# 3    AM  Amazonas      Manaus     NORTE
# 4    BA     Bahia    Salvador  NORDESTE

# %%
ufs = [x for x in df0.to_dict(orient='records')]
ufs
# Out:
# [{'sigla': 'AC', 'estado': 'Acre', 'capital': 'Rio Branco', 'regiao': 'NORTE'},
#  {'sigla': 'AL',
#   'estado': 'Alagoas',
#   'capital': 'Maceió',
#   'regiao': 'NORDESTE'},
#  {'sigla': 'AP', 'estado': 'Amapá', 'capital': 'Macapá', 'regiao': 'NORTE'},
#  {'sigla': 'AM', 'estado': 'Amazonas', 'capital': 'Manaus', 'regiao': 'NORTE'},
#  {'sigla': 'BA',
#   'estado': 'Bahia',
#   'capital': 'Salvador',
#   'regiao': 'NORDESTE'},
#  {'sigla': 'CE',
#   'estado': 'Ceará',
#   'capital': 'Fortaleza',
#   'regiao': 'NORDESTE'},
#  {'sigla': 'DF',
#   'estado': 'Distrito Federal',
#   'capital': 'Brasília',
#   'regiao': 'CENTROESTE'},
#  {'sigla': 'ES',
#   'estado': 'Espírito Santo',
#   'capital': 'Vitória',
#   'regiao': 'SUDESTE'},
#  {'sigla': 'GO',
#   'estado': 'Goiás',
#   'capital': 'Goiânia',
#   'regiao': 'CENTROESTE'},
#  {'sigla': 'MA',
#   'estado': 'Maranhão',
#   'capital': 'São Luís',
#   'regiao': 'NORDESTE'},
#  {'sigla': 'MT',
#   'estado': 'Mato Grosso',
#   'capital': 'Cuiabá',
#   'regiao': 'CENTROESTE'},
#  {'sigla': 'MS',
#   'estado': 'Mato Grosso do Sul',
#   'capital': 'Campo Grande',
#   'regiao': 'CENTROESTE'},
#  {'sigla': 'MG',
#   'estado': 'Minas Gerais',
#   'capital': 'Belo Horizonte',
#   'regiao': 'SUDESTE'},
#  {'sigla': 'PR', 'estado': 'Paraná', 'capital': 'Curitiba', 'regiao': 'SUL'},
#  {'sigla': 'PB',
#   'estado': 'Paraíba',
#   'capital': 'João Pessoa',
#   'regiao': 'NORDESTE'},
#  {'sigla': 'PA', 'estado': 'Pará', 'capital': 'Belém', 'regiao': 'NORTE'},
#  {'sigla': 'PE',
#   'estado': 'Pernambuco',
#   'capital': 'Recife',
#   'regiao': 'NORDESTE'},
#  {'sigla': 'PI',
#   'estado': 'Piauí',
#   'capital': 'Teresina',
#   'regiao': 'NORDESTE'},
#  {'sigla': 'RN',
#   'estado': 'Rio Grande do Norte',
#   'capital': 'Natal',
#   'regiao': 'NORDESTE'},
#  {'sigla': 'RS',
#   'estado': 'Rio Grande do Sul',
#   'capital': 'Porto Alegre',
#   'regiao': 'SUL'},
#  {'sigla': 'RJ',
#   'estado': 'Rio de Janeiro',
#   'capital': 'Rio de Janeiro',
#   'regiao': 'SUDESTE'},
#  {'sigla': 'RO',
#   'estado': 'Rondônia',
#   'capital': 'Porto Velho',
#   'regiao': 'NORTE'},
#  {'sigla': 'RR',
#   'estado': 'Roraima',
#   'capital': 'Boa Vista',
#   'regiao': 'NORTE'},
#  {'sigla': 'SC',
#   'estado': 'Santa Catarina',
#   'capital': 'Florianópolis',
#   'regiao': 'SUL'},
#  {'sigla': 'SE',
#   'estado': 'Sergipe',
#   'capital': 'Aracaju',
#   'regiao': 'NORDESTE'},
#  {'sigla': 'SP',
#   'estado': 'São Paulo',
#   'capital': 'São Paulo',
#   'regiao': 'SUDESTE'},
#  {'sigla': 'TO',
#   'estado': 'Tocantins',
#   'capital': 'Palmas',
#   'regiao': 'NORTE'}]

# %%
ufs = [Estado(**x) for x in df0.to_dict(orient='records')]
ufs
# Out:
# [Estado(sigla='AC', estado='Acre', capital='Rio Branco', regiao='NORTE'),
#  Estado(sigla='AL', estado='Alagoas', capital='Maceió', regiao='NORDESTE'),
#  Estado(sigla='AP', estado='Amapá', capital='Macapá', regiao='NORTE'),
#  Estado(sigla='AM', estado='Amazonas', capital='Manaus', regiao='NORTE'),
#  Estado(sigla='BA', estado='Bahia', capital='Salvador', regiao='NORDESTE'),
#  Estado(sigla='CE', estado='Ceará', capital='Fortaleza', regiao='NORDESTE'),
#  Estado(sigla='DF', estado='Distrito Federal', capital='Brasília', regiao='CENTROESTE'),
#  Estado(sigla='ES', estado='Espírito Santo', capital='Vitória', regiao='SUDESTE'),
#  Estado(sigla='GO', estado='Goiás', capital='Goiânia', regiao='CENTROESTE'),
#  Estado(sigla='MA', estado='Maranhão', capital='São Luís', regiao='NORDESTE'),
#  Estado(sigla='MT', estado='Mato Grosso', capital='Cuiabá', regiao='CENTROESTE'),
#  Estado(sigla='MS', estado='Mato Grosso do Sul', capital='Campo Grande', regiao='CENTROESTE'),
#  Estado(sigla='MG', estado='Minas Gerais', capital='Belo Horizonte', regiao='SUDESTE'),
#  Estado(sigla='PR', estado='Paraná', capital='Curitiba', regiao='SUL'),
#  Estado(sigla='PB', estado='Paraíba', capital='João Pessoa', regiao='NORDESTE'),
#  Estado(sigla='PA', estado='Pará', capital='Belém', regiao='NORTE'),
#  Estado(sigla='PE', estado='Pernambuco', capital='Recife', regiao='NORDESTE'),
#  Estado(sigla='PI', estado='Piauí', capital='Teresina', regiao='NORDESTE'),
#  Estado(sigla='RN', estado='Rio Grande do Norte', capital='Natal', regiao='NORDESTE'),
#  Estado(sigla='RS', estado='Rio Grande do Sul', capital='Porto Alegre', regiao='SUL'),
#  Estado(sigla='RJ', estado='Rio de Janeiro', capital='Rio de Janeiro', regiao='SUDESTE'),
#  Estado(sigla='RO', estado='Rondônia', capital='Porto Velho', regiao='NORTE'),
#  Estado(sigla='RR', estado='Roraima', capital='Boa Vista', regiao='NORTE'),
#  Estado(sigla='SC', estado='Santa Catarina', capital='Florianópolis', regiao='SUL'),
#  Estado(sigla='SE', estado='Sergipe', capital='Aracaju', regiao='NORDESTE'),
#  Estado(sigla='SP', estado='São Paulo', capital='São Paulo', regiao='SUDESTE'),
#  Estado(sigla='TO', estado='Tocantins', capital='Palmas', regiao='NORTE')]

# %%
municipios
# Out:
#       UF  CODIGO_MUNICIPIO            NOME_MUNICIPIO  DIA  MES
# 0     AM            130080                     Borba    1    1
# 1     PA            150611                 Quatipuru    1    1
# 2     PA            150796                Terra Alta    1    1
# 3     TO            170770                Filadélfia    1    1
# 4     TO            171370  Monte Santo do Tocantins    1    1
# ...   ..               ...                       ...  ...  ...
# 5565  SP            350090                    Altair   31   12
# 5566  SC            420550                 Fraiburgo   31   12
# 5567  SC            420990                   Lontras   31   12
# 5568  RS            430045                   Alegria   31   12
# 5569  MT            510140                  Aripuanã   31   12
#
# [5570 rows x 5 columns]

# %%
df = copy(municipios)

# %%
Municipio()
# Out:
# Municipio(estado='', nome='', data=None, mes=0, dia=0)

# %%
# [x for x in df.to_dict(orient='records')]

# %%
df.head()
# Out:
#    UF  CODIGO_MUNICIPIO            NOME_MUNICIPIO  DIA  MES
# 0  AM            130080                     Borba    1    1
# 1  PA            150611                 Quatipuru    1    1
# 2  PA            150796                Terra Alta    1    1
# 3  TO            170770                Filadélfia    1    1
# 4  TO            171370  Monte Santo do Tocantins    1    1

# %%
df0.head()
# Out:
#   sigla    estado     capital    regiao
# 0    AC      Acre  Rio Branco     NORTE
# 1    AL   Alagoas      Maceió  NORDESTE
# 2    AP     Amapá      Macapá     NORTE
# 3    AM  Amazonas      Manaus     NORTE
# 4    BA     Bahia    Salvador  NORDESTE

# %%
# df['estado'] =
# df.loc[df.UF == df0.sigla
df0.sigla
# Out:
# 0     AC
# 1     AL
# 2     AP
# 3     AM
# 4     BA
# 5     CE
# 6     DF
# 7     ES
# 8     GO
# 9     MA
# 10    MT
# 11    MS
# 12    MG
# 13    PR
# 14    PB
# 15    PA
# 16    PE
# 17    PI
# 18    RN
# 19    RS
# 20    RJ
# 21    RO
# 22    RR
# 23    SC
# 24    SE
# 25    SP
# 26    TO
# Name: sigla, dtype: object

# %%
df
# Out:
#       UF  CODIGO_MUNICIPIO            NOME_MUNICIPIO  DIA  MES
# 0     AM            130080                     Borba    1    1
# 1     PA            150611                 Quatipuru    1    1
# 2     PA            150796                Terra Alta    1    1
# 3     TO            170770                Filadélfia    1    1
# 4     TO            171370  Monte Santo do Tocantins    1    1
# ...   ..               ...                       ...  ...  ...
# 5565  SP            350090                    Altair   31   12
# 5566  SC            420550                 Fraiburgo   31   12
# 5567  SC            420990                   Lontras   31   12
# 5568  RS            430045                   Alegria   31   12
# 5569  MT            510140                  Aripuanã   31   12
#
# [5570 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UF                5570 non-null   object
#  1   CODIGO_MUNICIPIO  5570 non-null   int64
#  2   NOME_MUNICIPIO    5570 non-null   object
#  3   DIA               5570 non-null   int64
#  4   MES               5570 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 217.7+ KB

# %%
df.applymap(lambda x: type(x))
# Out:
#                  UF CODIGO_MUNICIPIO NOME_MUNICIPIO            DIA  \
# 0     <class 'str'>    <class 'int'>  <class 'str'>  <class 'int'>
# 1     <class 'str'>    <class 'int'>  <class 'str'>  <class 'int'>
# 2     <class 'str'>    <class 'int'>  <class 'str'>  <class 'int'>
# 3     <class 'str'>    <class 'int'>  <class 'str'>  <class 'int'>
# 4     <class 'str'>    <class 'int'>  <class 'str'>  <class 'int'>
# ...             ...              ...            ...            ...
# 5565  <class 'str'>    <class 'int'>  <class 'str'>  <class 'int'>
# 5566  <class 'str'>    <class 'int'>  <class 'str'>  <class 'int'>
# 5567  <class 'str'>    <class 'int'>  <class 'str'>  <class 'int'>
# 5568  <class 'str'>    <class 'int'>  <class 'str'>  <class 'int'>
# 5569  <class 'str'>    <class 'int'>  <class 'str'>  <class 'int'>
#
#                 MES
# 0     <class 'int'>
# 1     <class 'int'>
# 2     <class 'int'>
# 3     <class 'int'>
# 4     <class 'int'>
# ...             ...
# 5565  <class 'int'>
# 5566  <class 'int'>
# 5567  <class 'int'>
# 5568  <class 'int'>
# 5569  <class 'int'>
#
# [5570 rows x 5 columns]

# %%
df.apply(lambda x: type(x))
# Out:
# UF                  <class 'pandas.core.series.Series'>
# CODIGO_MUNICIPIO    <class 'pandas.core.series.Series'>
# NOME_MUNICIPIO      <class 'pandas.core.series.Series'>
# DIA                 <class 'pandas.core.series.Series'>
# MES                 <class 'pandas.core.series.Series'>
# dtype: object

# %%
df.loc[:, ['MES', 'DIA']]
# Out:
#       MES  DIA
# 0       1    1
# 1       1    1
# 2       1    1
# 3       1    1
# 4       1    1
# ...   ...  ...
# 5565   12   31
# 5566   12   31
# 5567   12   31
# 5568   12   31
# 5569   12   31
#
# [5570 rows x 2 columns]

# %%
df.loc[:, ['MES', 'DIA']].apply(lambda x: x)
# Out:
#       MES  DIA
# 0       1    1
# 1       1    1
# 2       1    1
# 3       1    1
# 4       1    1
# ...   ...  ...
# 5565   12   31
# 5566   12   31
# 5567   12   31
# 5568   12   31
# 5569   12   31
#
# [5570 rows x 2 columns]

# %%
df.loc[:, ['DIA', 'MES']].values
# Out:
# array([[ 1,  1],
#        [ 1,  1],
#        [ 1,  1],
#        ...,
#        [31, 12],
#        [31, 12],
#        [31, 12]])

# %%
df.sort_values(by='NOME_MUNICIPIO').to_json(
    data_path / 'municipios_br.json', orient='records'
)
