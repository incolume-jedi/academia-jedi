# %%
import pandas as pd
import tqdm

# %%
tqdm.tqdm.pandas()

# %%
df = pd.DataFrame({'numb': range(1_000_000)})

# %%
df['sqrt'] = df.numb.progress_apply(lambda x: x**0.5)
# Out:
# 100%|██████████| 1000000/1000000 [00:01<00:00, 925391.58it/s]
